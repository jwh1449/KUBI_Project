# %%
# !pip install nlptutti
# Out:
# Collecting nlptutti
#   Downloading nlptutti-0.0.0.8-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from nlptutti) (2.2.2)
# Collecting jiwer (from nlptutti)
#   Downloading jiwer-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer->nlptutti) (8.1.8)
# Collecting rapidfuzz>=3.9.7 (from jiwer->nlptutti)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->nlptutti) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->nlptutti) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->nlptutti) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->nlptutti) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->nlptutti) (1.17.0)
# Downloading nlptutti-0.0.0.8-py3-none-any.whl (10 kB)
# Downloading jiwer-3.1.0-py3-none-any.whl (22 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer, nlptutti
# Successfully installed jiwer-3.1.0 nlptutti-0.0.0.8 rapidfuzz-3.13.0

# %%
from transformers import WhisperForConditionalGeneration, WhisperProcessor
import os
import json
import librosa
import torch
import random
import nlptutti as metrics

random.seed(42)

# 모델과 프로세서 로드
model = WhisperForConditionalGeneration.from_pretrained("jwh1449/whisper_base_KoSpeech")
processor = WhisperProcessor.from_pretrained("jwh1449/whisper_base_KoSpeech")
model.generation_config.forced_decoder_ids = None

# 변환할 음성 파일 경로 설정
audio_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech원본"
json_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech정답"

# 모든 WAV 파일 목록 가져오기
all_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
selected_files = random.sample(all_files, min(100, len(all_files)))

cer_list = []

for file_name in selected_files:
    file_path = os.path.join(audio_folder, file_name)
    json_path = os.path.join(json_folder, file_name.replace(".wav", ".txt"))

    print(f"Processing: {file_name}")

    # 전체 파일 한 번에 로드 (분할 없음)
    audio, sr = librosa.load(file_path, sr=16000)
    input_features = processor(audio, sampling_rate=sr, return_tensors="pt").input_features

    with torch.no_grad():
        generated_ids = model.generate(
            input_features,
            language="ko",
            task="transcribe"
        )

    asr_text = processor.decode(generated_ids[0], skip_special_tokens=True)

    if os.path.exists(json_path):
        with open(json_path, "r", encoding="utf-8") as f:
            data = f.read().strip()

            cer_result = metrics.get_cer(data, asr_text)
            cer = cer_result['cer']
            cer_list.append(cer)
            print(f"CER: {cer:.4f}")
    else:
        print("No reference text found.")

    print(f"Transcription: {asr_text}")
    print(f"Reference: {data}")
    print("-" * 50)

if cer_list:
    print(f"\nAverage CER: {sum(cer_list)/len(cer_list):.4f}")
# Out:
# Processing: KsponSpeech_539357.wav
# CER: 0.0833
# Transcription: 나는 어제 니 표정 보고 알았어. 걔는 진짜 자기 싫어하는구나.
# Reference: 나는 어제 니 표정 보고 알았어. 쟤는 진짜 타기 싫어하는구나.
# --------------------------------------------------
# Processing: KsponSpeech_608138.wav
# CER: 0.0556
# Transcription:  그 제목 뭐였지? 우리들의 월급은 정 정당 안 가?
# Reference: 그 제목 뭐였지? 우리들의 월급은 정 정당한가?
# --------------------------------------------------
# Processing: KsponSpeech_618809.wav
# CER: 0.0469
# Transcription:  그 내 친구의 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비 비싼대가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그 그냥 퍼스널 컬러랑
# Reference: 그 내 친구에 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비 비싼 데가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑
# --------------------------------------------------
# Processing: KsponSpeech_524718.wav
# CER: 0.2000
# Transcription:  응. 그래서 추천 많이 해서.
# Reference: 응. 그거는 추천 많이 해서
# --------------------------------------------------
# Processing: KsponSpeech_585605.wav
# CER: 0.0000
# Transcription:  찹쌀탕수육.
# Reference: 찹쌀탕수육.
# --------------------------------------------------
# Processing: KsponSpeech_589709.wav
# CER: 0.2500
# Transcription:  되게 연기사로잖아.
# Reference: 되게 연기 잘하잖아.
# --------------------------------------------------
# Processing: KsponSpeech_592791.wav
# CER: 0.5556
# Transcription:  수용이 아니라 수용이?
# Reference: 수응이 알아? 수응이
# --------------------------------------------------
# Processing: KsponSpeech_603838.wav
# CER: 0.1739
# Transcription:  이케 쫌 행사도 많고 쫌 성수기인가 봐 나름 그래가지구
# Reference: 이렇게 좀 행사도 많고 좀 성수기인가 봐. 나름 그래가지구
# --------------------------------------------------
# Processing: KsponSpeech_526034.wav
# CER: 0.1389
# Transcription:  지연보고 들어오라 그래. 지연보고 들어오라 그래. 경도시연보고 들어와야 돼. 내가 볼 거야. 내가 볼 거야. 내가 심사할 거야. 왠 적도 봐야겠다. 왠 적도 봐야겠다. 기초 소향 평가해가지고.
# Reference: 시험 보고 들어오라 그래 시험 보고 들어오라 그래. 경도 시험 보고 들어와야 돼. 내가 볼 거야 내가 볼 거야 내가 심사할 거야 면접도 봐야겠다 면접도 봐야겠다 기초소양 평가해가지고
# --------------------------------------------------
# Processing: KsponSpeech_608909.wav
# CER: 0.0857
# Transcription:  어차피 매출이 얼마가 나오든 물론 다양한 상관이 없지만 어차피 난 똑같이 돈받으니까.
# Reference: 어차피 매출이 얼마가 나오든 물론 나랑은 상관이 없지만. 어차피 난 똑같이 돈 받으니까.
# --------------------------------------------------
# Processing: KsponSpeech_534277.wav
# CER: 0.0000
# Transcription: 아니야 애증은 아니야.
# Reference: 아니야 애증은 아니야.
# --------------------------------------------------
# Processing: KsponSpeech_524663.wav
# CER: 0.0000
# Transcription: 맞아.
# Reference: 맞아.
# --------------------------------------------------
# Processing: KsponSpeech_506541.wav
# CER: 0.0000
# Transcription:  근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까
# Reference: 근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까
# --------------------------------------------------
# Processing: KsponSpeech_550994.wav
# CER: 0.0588
# Transcription: 음 잘했어. 그럼 이제 배워볼 생각은 없어?
# Reference: 으음 잘했어. 그럼 이제 배워 볼 생각은 없어?
# --------------------------------------------------
# Processing: KsponSpeech_610899.wav
# CER: 0.2667
# Transcription:  얼마나 신선했음? 앨벌레가 나은니.
# Reference: 얼마나 신선했으면 애벌레가 나왔니
# --------------------------------------------------
# Processing: KsponSpeech_544963.wav
# CER: 0.0000
# Transcription:  아까 무슨 얘기하고 있었지?
# Reference: 아까 무슨 얘기하고 있었지.
# --------------------------------------------------
# Processing: KsponSpeech_566814.wav
# CER: 0.8333
# Transcription:  네. 마지막에 오
# Reference: 네. 말씀하세요.
# --------------------------------------------------
# Processing: KsponSpeech_617728.wav
# CER: 0.1667
# Transcription:  쫌 들어가야 돼.
# Reference: 좀 들어가야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_619452.wav
# CER: 0.1111
# Transcription:  나는 근데 생각보다 늦게 좋아해가지고 수능 끝나고 핏담물 나와서 그때부터 좋아했어.
# Reference: 나는 근데 생각보다 늦게 좋아해가지구 수능 끝나고 피 땀 눈물 나와서 그때부터 좋아했어.
# --------------------------------------------------
# Processing: KsponSpeech_609816.wav
# CER: 0.0870
# Transcription: 근데 난 이번에 좀 열심히 해볼게 그러면 끊으면 만약에.
# Reference: 근데 나는 이번에 좀 열심히 해 볼게 그러면. 끊으면 만약에
# --------------------------------------------------
# Processing: KsponSpeech_594199.wav
# CER: 0.0192
# Transcription: 나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까 그냥 거기는 좀 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# Reference: 나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까. 그냥 거기는 쫌 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# --------------------------------------------------
# Processing: KsponSpeech_592002.wav
# CER: 0.0000
# Transcription:  발 뺀 거지?
# Reference: 발 뺀 거지?
# --------------------------------------------------
# Processing: KsponSpeech_555828.wav
# CER: 0.0833
# Transcription: 나는? 나는 내 여시 반에 알바가야 되잖아. 오늘 처음 가잖아.
# Reference: 나는? 나는 나 여섯 시 반에 알바 가야 되잖아. 오늘 처음 가잖아.
# --------------------------------------------------
# Processing: KsponSpeech_544438.wav
# CER: 1.0000
# Transcription:  응.
# Reference: 음.
# --------------------------------------------------
# Processing: KsponSpeech_619033.wav
# CER: 0.2500
# Transcription:  오니어. 전복만 전복만 전복스
# Reference: 아니야. 전복만. 전복만. 전복쓰
# --------------------------------------------------
# Processing: KsponSpeech_549073.wav
# CER: 0.0000
# Transcription:  역배를 하면은 커지지.
# Reference: 역배를 하면은 커지지.
# --------------------------------------------------
# Processing: KsponSpeech_595616.wav
# CER: 0.0847
# Transcription:  근데 아 아일 안 좋아하면 사실 힘들지. 애들 다르 근데 애들 TMI 얘기하는 거 보면 아 그게 너무 싫구나. 나는 좀 귀엽다고 얘기할래 그랬는데. 싫구나.
# Reference: 근데 아 아일 안 좋아하면 사실 힘들지. 애들 다루 근데 애들 tmi 얘기하는 거 보면 아 그게 너무 싫구나? 나는 좀 귀엽다고 얘기할려 그랬는데. 싫구나.
# --------------------------------------------------
# Processing: KsponSpeech_529406.wav
# CER: 0.3889
# Transcription:  응. 알린아. 본인이 막 하고 싶어. 못 참아해.
# Reference: 금 난리 나. 본인이 말하고 싶어 갖고 못 참아 해.
# --------------------------------------------------
# Processing: KsponSpeech_536673.wav
# CER: 0.1579
# Transcription:  막 어 진짜 막 잔인하게 잘 벼서 해가지고 그니까 막 잔인한 장렬한 안 나오는데 어 깜놀도 좀 있고
# Reference: 막 어 진짜 막 잔인하게 잘 묘사해가지고 그니까 막 잔인한 장면은 안 나오는데 어 깜놀도 쫌 있구.
# --------------------------------------------------
# Processing: KsponSpeech_531484.wav
# CER: 0.0300
# Transcription:  어. 아침에? 아침에 이제 보통 다르지. 내가 학원을 갈 때가 있고 안 갈 때 있으니까 월 수금 같은 경우는 학원을 내가 다니니까 좀 평소 보다 일찍 일어나고 이제 그렇지 않을 때는 화목 같은 경우는 그냥 내 일어나고 싶은 날 일어나 일어나는 그런 식이지. 너는.
# Reference: 응. 아침에? 아침에 이제 보통 다르지. 내가 학원을 갈 때가 있고 안 갈 때 있으니까. 월 수 금 같은 경우는 학원을 내가 다니니까 좀 평소보다 일찍 일어나고 이제 그렇지 않을 때는 화 목 같은 경우는 그냥 내가 일어나고 싶은 날 일어 일어나는 그런 식이지. 너는?
# --------------------------------------------------
# Processing: KsponSpeech_550925.wav
# CER: 0.0000
# Transcription:  나는 나는 나는 두 번인가 세 번 봤는데? 나는 언제 그렇게 봤지?
# Reference: 나는 나는 나는 두 번인가 세 번 봤는데? 나는 언제 그렇게 봤지?
# --------------------------------------------------
# Processing: KsponSpeech_568561.wav
# CER: 0.0909
# Transcription: 그거 올해 됐어. 나는 보통 그거 한 한 달 쓰거든 그 헤어팩
# Reference: 그거 오래됐어. 나는 보통 그거 한 한 달 쓰거든 그 헤어 팩
# --------------------------------------------------
# Processing: KsponSpeech_594468.wav
# CER: 0.0000
# Transcription:  웃기네.
# Reference: 웃기네.
# --------------------------------------------------
# Processing: KsponSpeech_564413.wav
# CER: 0.1071
# Transcription: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실이 낫는데
# Reference: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실 남맨데
# --------------------------------------------------
# Processing: KsponSpeech_544813.wav
# CER: 0.1875
# Transcription:  마우스 샀잖아. 아 마우스는 원래 입건다.
# Reference: 마우스 샀잖아 아 마우스는 원래 있구.
# --------------------------------------------------
# Processing: KsponSpeech_586007.wav
# CER: 0.1429
# Transcription:  물 아 그래? 못 할걸?
# Reference: 물 아 구래? 못할걸?
# --------------------------------------------------
# Processing: KsponSpeech_515652.wav
# CER: 0.0000
# Transcription: 아 진짜로?
# Reference: 아 진짜로?
# --------------------------------------------------
# Processing: KsponSpeech_509494.wav
# CER: 0.0000
# Transcription: 그치. 정말
# Reference: 그치 정말.
# --------------------------------------------------
# Processing: KsponSpeech_622439.wav
# CER: 0.0000
# Transcription: 어. 있어 그런 거.
# Reference: 어. 있어 그런 거.
# --------------------------------------------------
# Processing: KsponSpeech_523022.wav
# CER: 0.6000
# Transcription:  저기 헤어어.
# Reference: 저기 혜화역
# --------------------------------------------------
# Processing: KsponSpeech_517134.wav
# CER: 0.1967
# Transcription:  그니까 그냥 모든 게 다 그런 거야. 지금 상상 상상이 저러니까 뭐 들으면 또 자식도 뭐 잘못한 것도 있지만 뭐 내일 졸을 잘 못 하고 있나. 그런 생각도 있고.
# Reference: 그니까 그냥 모든 게 다 그런 거야 지금 상황 형 상황이 요러니까. 어뜨케 보면 또 자식도 뭐 잘못한 것도 있지만. 뭐 내조를 잘못하고 있나? 그런 생각도 있.
# --------------------------------------------------
# Processing: KsponSpeech_602446.wav
# CER: 0.0833
# Transcription: 그까 최근 말고 쫌 덜 최근 그니까 내신 시험 할 때쯤에 최근?
# Reference: 그니까 최근 말고 좀 덜 최근 그니까 내신 시험할 때쯤에 최근
# --------------------------------------------------
# Processing: KsponSpeech_531126.wav
# CER: 0.4138
# Transcription:  다섯 시 나 요 여섯 시까지 했지? 원래 나인트 바이브잖아. 그래서.
# Reference: 다섯 시나 여 여섯 시까지겠지? 원래 nine to five잖아 그래서.
# --------------------------------------------------
# Processing: KsponSpeech_566911.wav
# CER: 0.0000
# Transcription:  근데 중국에서 우연히 중국 사람들이 그 돌로 뭐
# Reference: 근데 중국에서 우연히 중국 사람들이 그 돌로 뭐.
# --------------------------------------------------
# Processing: KsponSpeech_578097.wav
# CER: 0.0455
# Transcription:  여성 증병이라 글쎄 근데 그런 것들이 진행이 될려면은
# Reference: 여성 징병이라 글쎄 근데 그런 것들이 진행이 될려면은
# --------------------------------------------------
# Processing: KsponSpeech_585961.wav
# CER: 0.3636
# Transcription: 십니까 비슷하�다는 거지?
# Reference: 심리가 비슷하다는 거지?
# --------------------------------------------------
# Processing: KsponSpeech_601933.wav
# CER: 0.0909
# Transcription:  어쨌든 적당히 먹어 가야지.
# Reference: 어쨌든 적당히 먹어야지.
# --------------------------------------------------
# Processing: KsponSpeech_593839.wav
# CER: 0.3333
# Transcription:  나랑 잘 많더라고 다 이쁘봤고.
# Reference: 나랑 잘 맞더라고. 다 A 맞고.
# --------------------------------------------------
# Processing: KsponSpeech_496960.wav
# CER: 0.1765
# Transcription: 온통 쏠릴 거 같아서 쓰리지를 선든 못 하게 했어서 포장도 그렇게 많은 그건 아닌데.
# Reference: 온통 쏠릴 거 같아서 쓰리디를 선뜻 못하겠 겠어서 포장도 그렇게 많은 그거는 아닌데.
# --------------------------------------------------
# Processing: KsponSpeech_521636.wav
# CER: 0.0984
# Transcription: 왜냐면 빨리 따 빨리 해 시작을 해야지 그게 빨리 쌓여 쌓여가지고 경력이 쌓이니까. 여기 쪼금 있다가 하면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# Reference: 왜냐면 빨리 따야 빨리해 시작을 해야지 그게 빨리 쌓여 쌓여가지고 경력이 쌓이니까. 이게 조금 이따가 하면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# --------------------------------------------------
# Processing: KsponSpeech_577689.wav
# CER: 0.0588
# Transcription: 어 거 아 누나는 이제 집에 없지 결혼했지 집에 없 근데 가끔 누나 가서 도와줄 땐 있는데
# Reference: 어. 커 아 누나는 이제 집에 없지. 결혼 했지. 집에 없 근데 가끔 누나 가서 도와줄 수 있는데
# --------------------------------------------------
# Processing: KsponSpeech_608974.wav
# CER: 0.0000
# Transcription:  남자친구가 없어 하면은 굉장히 그 어머니가 불안해하더라고. 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데
# Reference: 남자 친구가 없어 하면은 굉장히 그 어머니가 불안해하더라고. 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데
# --------------------------------------------------
# Processing: KsponSpeech_609729.wav
# CER: 0.0385
# Transcription:  근데 난 여기서 더이상 빼면은 더이상 나는 작은 마음이 될 거 같애.
# Reference: 데 난 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 거 같애
# --------------------------------------------------
# Processing: KsponSpeech_573323.wav
# CER: 0.0400
# Transcription: 그래서 내가 그 신경 치료까지 했단 말야 신경이 죽어가지고
# Reference: 그래서 내가 그 신경 치료까지 했단 말이야. 신경이 죽어가지고.
# --------------------------------------------------
# Processing: KsponSpeech_610233.wav
# CER: 0.0000
# Transcription:  그니까 그 생각 하니까.
# Reference: 그니까 그 생각하니까.
# --------------------------------------------------
# Processing: KsponSpeech_574615.wav
# CER: 0.1724
# Transcription:  이까번에 이제 십 프로 가산점을 주니까 어 구십 프로 백 분이 맞는 얘들도
# Reference: 이과 꺼는 이제 십 프로 가산점을 주니까 어 구십 프로 백분위 맡는 얘들도
# --------------------------------------------------
# Processing: KsponSpeech_510618.wav
# CER: 0.0732
# Transcription:  완전 아니 백 삼십 이 명 뽑는데 컷 점수가 백 백 내 점수야 컷 점수가 그니까 나랑 동점자가 이제 꿀찐 거야.
# Reference: 완전 아니 백 삼십 이 명 뽑는데 컷 점수가 백 배 내 점수야 컷 점수가 그니까 나랑 동점자가 이제 꼴진 거야
# --------------------------------------------------
# Processing: KsponSpeech_576594.wav
# CER: 0.0556
# Transcription: 그런 데가 있구나. 니가 가자고 온 데가 거기야?
# Reference: 그런 데가 있구나 니가 가자고 한데가 거기야?
# --------------------------------------------------
# Processing: KsponSpeech_542633.wav
# CER: 0.1667
# Transcription:  아빠 오십 살 된다 했던 게 없으진 같은데 진짜.
# Reference: 아빠 오십 살 된다 했던 게 엊그제 같은데 진짜.
# --------------------------------------------------
# Processing: KsponSpeech_588225.wav
# CER: 0.1346
# Transcription:  그런가? 그때마다 기가 이케 뭘 넣어주는 안 넣어준 건 아니거든. 넣어주는 거 넣어줬는데 좀 좀 내가 느끼기에는 얘가 나를 생각해서 사오 거라기보다는 집에 남는 거 있잖아. 뭔가 엄마가 사오셨는데 집에 쟁여두고 있다가 하나씩 갔다가 나를 주는 거 같은.
# Reference: 고런 거? 그때마다 걔가 이렇게 뭘 넣어주는 안 넣어준 건 아니거든? 넣어주긴 넣어줬는데 쫌 쫌 내가 느끼기에는 얘가 나를 생각해서 사 온 거라기보다는 집에 남는 거 있잖아? 뭔가 엄마가 사 오셨는데 집에 이렇게 쟁여두고 있다가 하나씩 갖다가 나를 주는 거 같은.
# --------------------------------------------------
# Processing: KsponSpeech_517345.wav
# CER: 0.0606
# Transcription:  아 내 생각엔 안경 땜에 쫌 걸쳐지는 게 불편했나? 근데 너 안경 못으니까 딴 사람 같아.
# Reference: 아 내 생각엔 안경 땜에 좀 걸쳐지는 게 불편했나? 근데 너 안경 벗으니까 딴 사람 같아.
# --------------------------------------------------
# Processing: KsponSpeech_617232.wav
# CER: 0.0000
# Transcription:  자기가 너무 크니까.
# Reference: 자기가 너무 크니까.
# --------------------------------------------------
# Processing: KsponSpeech_527157.wav
# CER: 0.0857
# Transcription:  그럴 거 같지? 우리 다음 주 부터 둘 다 출근할 거 같으니까? 주말 주말은 넘으니까 금요일?
# Reference: 그럴 거 같지? 우리 다음 주부터 둘 다 출근할 거 같으니까. 주말 주말은 너무하니까 금요일?
# --------------------------------------------------
# Processing: KsponSpeech_561775.wav
# CER: 0.2667
# Transcription:  그니까 탄산업념 먹고 싶을 때 있잖아.
# Reference: 이까 탄산음료 먹고 싶을 때 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_551757.wav
# CER: 0.0625
# Transcription: 군 그냥 나오 혼자 그렇게 생각하는 건데.
# Reference: 군 그냥 나 혼자 그렇게 생각하는 건데?
# --------------------------------------------------
# Processing: KsponSpeech_605994.wav
# CER: 0.0000
# Transcription:  나 공부해야 돼.
# Reference: 나 공부해야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_502392.wav
# CER: 0.0769
# Transcription: 근데 약간 우리 오빠는 그거 잘해. 자기 혼자 영어폭보마케팅 다 해.
# Reference: 근데 약간 우리 오빠는 그거 잘해. 자기 혼자 영업 홍보 마케팅 다 해.
# --------------------------------------------------
# Processing: KsponSpeech_573125.wav
# CER: 0.1000
# Transcription:  아 받은 거여 엄마한테?
# Reference: o. 아 받은 거여. 엄마한테?
# --------------------------------------------------
# Processing: KsponSpeech_611873.wav
# CER: 0.0625
# Transcription:  그 해리포터 영화 자체가 전체 다 영국인이고 거기서 나오는 동양인이라도 영국에 사는 사람이고 그래서 되게 사람들이
# Reference: 그 해리포터 영화 자체가 전체 다 영국인이고 거기서 나오는 동양인이라도 영국에 사는 사람이고 계속되게 사람들이
# --------------------------------------------------
# Processing: KsponSpeech_549930.wav
# CER: 0.1228
# Transcription:  살 건 아니고 그냥 혼자서 아이쇼핑을 하면서 혹이나 눈에 띄는 게 있다면 특히만으로 가는 거지. 꾸지 내가 뭘 살려고 가는 것은 아니다 그런 거지.
# Reference: 살 건 아니고 그냥 혼자서 아이 쇼핑을 하면서 혹이나 눈에 띄는 게 있다면 득템하러 가는 거지. 꾿이 내가 뭘 살려고 가는 것은 아니다 그런 거지.
# --------------------------------------------------
# Processing: KsponSpeech_584024.wav
# CER: 1.0000
# Transcription:  먹었으니까 나하자.
# Reference: 모가 수위가 낮아.
# --------------------------------------------------
# Processing: KsponSpeech_514225.wav
# CER: 0.2222
# Transcription:  그 첫 번째 연대에 못 가고 그 다음 연대 갔어.
# Reference: 그 첫 번째 년도에 못 가고 그 다음 연도에 갔어.
# --------------------------------------------------
# Processing: KsponSpeech_539926.wav
# CER: 0.2500
# Transcription: 그래 빨리 보내주고.
# Reference: 그래 빨리 보내줘
# --------------------------------------------------
# Processing: KsponSpeech_540647.wav
# CER: 0.0000
# Transcription: 너는 여행 안 가?
# Reference: 너는 여행 안 가?
# --------------------------------------------------
# Processing: KsponSpeech_505546.wav
# CER: 0.1333
# Transcription:  그 병인이라는 사람이 이하킷됐잖아. 너무 놀고 돈만 먹고 놀고 있는 거야.
# Reference: 그 병인이라는 사람이 이 학기 때 했잖아. 너무 놀고 돈만 먹고 놀고 있는 거야.
# --------------------------------------------------
# Processing: KsponSpeech_510540.wav
# CER: 0.5000
# Transcription: 끄치.
# Reference: 그치.
# --------------------------------------------------
# Processing: KsponSpeech_574951.wav
# CER: 0.3000
# Transcription:  몇 명 정도 있어? 어이기는 나가라 그랬다고? 그들은 약간 배척당하지 않을까?
# Reference: 몇 명 정도 있어? 어인의 나라가 있다고? 걔네는 약간 배척당하지 않을까?
# --------------------------------------------------
# Processing: KsponSpeech_547184.wav
# CER: 0.1905
# Transcription:  아 근데 무릎을 수 걔가 하는 말이 가끔씩 좀 약간 거부감이 될 때가 있긴 있었어. 그 동아리 같이 했었으니까.
# Reference: 아 근데 모르겠어. 걔가 하는 말이 가끔씩 쫌 약간 거부감이 들 때가 있긴 있었어. 동아릴 같이했었으니까.
# --------------------------------------------------
# Processing: KsponSpeech_596750.wav
# CER: 0.2778
# Transcription:  그래서 그냥 쫌 약간 입고가 입고 다음스러워.
# Reference: 그래서 그냥 좀 약간 입고 가기 부담스러워.
# --------------------------------------------------
# Processing: KsponSpeech_529908.wav
# CER: 0.6000
# Transcription: 에 나 싱쿨.
# Reference: 에 다 싱크홀.
# --------------------------------------------------
# Processing: KsponSpeech_612661.wav
# CER: 0.1053
# Transcription: 너무 아깝더라. 그거랑 같이 보는데 재미도 없고
# Reference: 너무 아깝더라. 누나랑 같이 보는데 재미도 없고
# --------------------------------------------------
# Processing: KsponSpeech_615557.wav
# CER: 0.0556
# Transcription:  그 홍보고대사 같은 거 아니면 내가 알기로는
# Reference: 그 홍보대사 같은 거 아니면 내가 알기로는.
# --------------------------------------------------
# Processing: KsponSpeech_536215.wav
# CER: 0.2609
# Transcription:  아 한 시 반 까지만 마시면 되지. 그때가 진짜 소리 있잖아.
# Reference: 한 한 시 반까지만 마시면 되지. 그때까진 지하철이 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_593491.wav
# CER: 0.0000
# Transcription:  올 땐 데리러 올 거야. 아니면 인천공항에서 만나던가.
# Reference: 올 땐 데리러 올 거야 아니면 인천공항에서 만나던가.
# --------------------------------------------------
# Processing: KsponSpeech_520848.wav
# CER: 0.1250
# Transcription:  치즈 한박 스테이크?
# Reference: 치즈 함박 스테이크?
# --------------------------------------------------
# Processing: KsponSpeech_585460.wav
# CER: 0.1667
# Transcription:  갔다? 어 면제 갔다 왔어 옛날에 갔다 왔구나.
# Reference: 갔다 온. 너 언제 갔다 왔어. 옛날에 갔다 왔구나.
# --------------------------------------------------
# Processing: KsponSpeech_611985.wav
# CER: 0.0000
# Transcription: 어 그치.
# Reference: 어 그치.
# --------------------------------------------------
# Processing: KsponSpeech_509670.wav
# CER: 0.1111
# Transcription:  청소년으로 보내 좀 싸.
# Reference: 청소년으로 보내 줌 싸.
# --------------------------------------------------
# Processing: KsponSpeech_592064.wav
# CER: 0.0000
# Transcription:  눈이 상태가 어떤지 계속 봐야 된대.
# Reference: 눈이 상태가 어떤지 계속 봐야 된대.
# --------------------------------------------------
# Processing: KsponSpeech_509147.wav
# CER: 0.0645
# Transcription:  수능 봤는데 재수였거든? 재수였는데 그 덕성여대인가? 거기 논술로 잡혔대. 어.
# Reference: 수능 봤는데 재수했거든? 재수했는데 그 덕성여대인가? 거기 논술로 잡혔대 어
# --------------------------------------------------
# Processing: KsponSpeech_608811.wav
# CER: 0.1026
# Transcription: 그리고 우리 저번 이번에도 저번 달인가? 몇 주 전에 고쳐 스카이더면서 하는 축 그 숙제 가지 않았어?
# Reference: 그리고 우리 저번 이번에도 저번 달인가 몇 주 전에 고척스카이돔에서 하는 축 그 축제 가지 않았어?
# --------------------------------------------------
# Processing: KsponSpeech_573353.wav
# CER: 0.0000
# Transcription: 그 시간 동안 내가 하고 싶은 걸 좀 하다가 이제
# Reference: 그 시간 동안 내가 하고 싶은 걸 좀 하다가 이제.
# --------------------------------------------------
# Processing: KsponSpeech_586029.wav
# CER: 0.1667
# Transcription: 우리 지금 하루 턴 입고 만났어.
# Reference: 우리 지금 하루 텀 있고 만났어.
# --------------------------------------------------
# Processing: KsponSpeech_563030.wav
# CER: 0.2667
# Transcription:  보니까? 뇌발근은? 돈 내는 거였어?
# Reference: 보니까? 연애에 발견은? 돈 내는 거였어?
# --------------------------------------------------
# Processing: KsponSpeech_538803.wav
# CER: 0.0000
# Transcription:  빼박이지 이러면.
# Reference: 빼박이지 이러면.
# --------------------------------------------------
# Processing: KsponSpeech_512824.wav
# CER: 0.1250
# Transcription: 가형이랑 승원이랑
# Reference: 가영이랑 승원이랑
# --------------------------------------------------
# Processing: KsponSpeech_575385.wav
# CER: 0.0488
# Transcription: 강식당 하면 이번에는 더 재밌을 거 같다. 피오 있어서 피오가 강식당 이번에 좀 톡톡히 할 거 같은데. 그치?
# Reference: 강 식당 하면 이번에는 더 재밌을 거 같다. 피오 있어서 피오가 강 식당 이번에 쫌 톡톡히 할 거 같은데. 그체.
# --------------------------------------------------
# Processing: KsponSpeech_600850.wav
# CER: 0.2941
# Transcription:  주말 수당은 줘도 약은 수당 안 주는데 많지.
# Reference: 주말 수당은 줘도 야근 수당 안 준 데는 많지.
# --------------------------------------------------
# Processing: KsponSpeech_574095.wav
# CER: 0.0000
# Transcription: 아 이번에 내 친구 경찰 공무원 준비하는데 붙었다?
# Reference: 아 이번에 내 친구 경찰공무원 준비하는데 붙었다.
# --------------------------------------------------
# Processing: KsponSpeech_576092.wav
# CER: 0.1667
# Transcription:  근 난만이구나.
# Reference: 근 날만이구나.
# --------------------------------------------------
#
# Average CER: 0.1517

# %%
from transformers import WhisperForConditionalGeneration, WhisperProcessor
import os
import json
import librosa
import torch
import random
import nlptutti as metrics

random.seed(42)

# 모델과 프로세서 로드
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-base")
processor = WhisperProcessor.from_pretrained("openai/whisper-base")
model.generation_config.forced_decoder_ids = None

# 변환할 음성 파일 경로 설정
audio_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech원본"
json_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech정답"

# 모든 WAV 파일 목록 가져오기
all_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
selected_files = random.sample(all_files, min(100, len(all_files)))

cer_list = []

for file_name in selected_files:
    file_path = os.path.join(audio_folder, file_name)
    json_path = os.path.join(json_folder, file_name.replace(".wav", ".txt"))

    print(f"Processing: {file_name}")

    # 전체 파일 한 번에 로드 (분할 없음)
    audio, sr = librosa.load(file_path, sr=16000)
    input_features = processor(audio, sampling_rate=sr, return_tensors="pt").input_features

    with torch.no_grad():
        generated_ids = model.generate(
            input_features,
            language="ko",
            task="transcribe"
        )

    asr_text = processor.decode(generated_ids[0], skip_special_tokens=True)

    if os.path.exists(json_path):
        with open(json_path, "r", encoding="utf-8") as f:
            data = f.read().strip()

            cer_result = metrics.get_cer(data, asr_text)
            cer = cer_result['cer']
            cer_list.append(cer)
            print(f"CER: {cer:.4f}")
    else:
        print("No reference text found.")

    print(f"Transcription: {asr_text}")
    print(f"Reference: {data}")
    print("-" * 50)

if cer_list:
    print(f"\nAverage CER: {sum(cer_list)/len(cer_list):.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/290M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.81k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# Processing: KsponSpeech_539357.wav
# You have passed task=transcribe, but also have set `forced_decoder_ids` to [[1, 50259], [2, 50359], [3, 50363]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of task=transcribe.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# CER: 0.2917
# Transcription:  나는 어제 네 표정 보고 알았어. 얘는 진짜 다이서라는구나.
# Reference: 나는 어제 니 표정 보고 알았어. 쟤는 진짜 타기 싫어하는구나.
# --------------------------------------------------
# Processing: KsponSpeech_608138.wav
# CER: 0.0556
# Transcription:  그 제목 뭐였지? 우리들의 월급은 정당한가?
# Reference: 그 제목 뭐였지? 우리들의 월급은 정 정당한가?
# --------------------------------------------------
# Processing: KsponSpeech_618809.wav
# CER: 0.1250
# Transcription:  내 친구의, 내 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 이제 비싼대가 있고 그냥 무난한 데가 있다 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑
# Reference: 그 내 친구에 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비 비싼 데가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑
# --------------------------------------------------
# Processing: KsponSpeech_524718.wav
# CER: 0.6000
# Transcription:  추천만 해서.
# Reference: 응. 그거는 추천 많이 해서
# --------------------------------------------------
# Processing: KsponSpeech_585605.wav
# CER: 0.6667
# Transcription:  탑사의 탕수요.
# Reference: 찹쌀탕수육.
# --------------------------------------------------
# Processing: KsponSpeech_589709.wav
# CER: 0.8889
# Transcription:  드디어 용기사로대로
# Reference: 되게 연기 잘하잖아.
# --------------------------------------------------
# Processing: KsponSpeech_592791.wav
# CER: 0.4444
# Transcription:  수롱이 알았어 수롱이?
# Reference: 수응이 알아? 수응이
# --------------------------------------------------
# Processing: KsponSpeech_603838.wav
# CER: 0.3478
# Transcription:  행사도 많고 성숙인가 봐 나름 그래가지고
# Reference: 이렇게 좀 행사도 많고 좀 성수기인가 봐. 나름 그래가지구
# --------------------------------------------------
# Processing: KsponSpeech_526034.wav
# CER: 0.1622
# Transcription:  지연보고 들어오라고 그래? 지연보고 들어오라고 그래? 경도시연보고 들어와야 돼 내가 볼 거야 내가 볼 거야 내가 심사할 거야 왼쪽도 봐야겠다 왼쪽도 봐야겠다 기초 소향 평가해가지고
# Reference: 시험 보고 들어오라 그래 시험 보고 들어오라 그래. 경도 시험 보고 들어와야 돼. 내가 볼 거야 내가 볼 거야 내가 심사할 거야 면접도 봐야겠다 면접도 봐야겠다 기초소양 평가해가지고
# --------------------------------------------------
# Processing: KsponSpeech_608909.wav
# CER: 0.0857
# Transcription:  어차피 매출이 얼마가 나오든 물론 다양한 상관이 없지만 어차피 난 똑같이 돈 받으니까
# Reference: 어차피 매출이 얼마가 나오든 물론 나랑은 상관이 없지만. 어차피 난 똑같이 돈 받으니까.
# --------------------------------------------------
# Processing: KsponSpeech_534277.wav
# CER: 0.1111
# Transcription:  아니야 애중은 아니야
# Reference: 아니야 애증은 아니야.
# --------------------------------------------------
# Processing: KsponSpeech_524663.wav
# CER: 0.0000
# Transcription:  맞아
# Reference: 맞아.
# --------------------------------------------------
# Processing: KsponSpeech_506541.wav
# CER: 0.1364
# Transcription:  근데 그거를 하려고 해도 맨날 과제가 나오니까
# Reference: 근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까
# --------------------------------------------------
# Processing: KsponSpeech_550994.wav
# CER: 0.0588
# Transcription:  음... 잘했어. 그럼 이제 배워볼 생각은 없어.
# Reference: 으음 잘했어. 그럼 이제 배워 볼 생각은 없어?
# --------------------------------------------------
# Processing: KsponSpeech_610899.wav
# CER: 0.2667
# Transcription:  얼마나 신선했으면 왜 불러가 나은니
# Reference: 얼마나 신선했으면 애벌레가 나왔니
# --------------------------------------------------
# Processing: KsponSpeech_544963.wav
# CER: 0.0000
# Transcription:  아까 무슨 얘기하고 있었지?
# Reference: 아까 무슨 얘기하고 있었지.
# --------------------------------------------------
# Processing: KsponSpeech_566814.wav
# CER: 0.0000
# Transcription:  네. 말씀하세요.
# Reference: 네. 말씀하세요.
# --------------------------------------------------
# Processing: KsponSpeech_617728.wav
# CER: 0.0000
# Transcription:  좀 들어가야 돼
# Reference: 좀 들어가야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_619452.wav
# CER: 0.1389
# Transcription:  나는 근데 생각보다 늦게 좋아해가지고 수능 끝나고 빛담룸을 나와서 그때부터 좋아했어.
# Reference: 나는 근데 생각보다 늦게 좋아해가지구 수능 끝나고 피 땀 눈물 나와서 그때부터 좋아했어.
# --------------------------------------------------
# Processing: KsponSpeech_609816.wav
# CER: 0.0870
# Transcription:  근데 난 이번에 좀 열심히 해볼게 그러면 끊으면 만약에
# Reference: 근데 나는 이번에 좀 열심히 해 볼게 그러면. 끊으면 만약에
# --------------------------------------------------
# Processing: KsponSpeech_594199.wav
# CER: 0.0192
# Transcription:  나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까 그냥 거기는 좀 더 어떻게 우리나라랑 다른지 알고 싶더라고
# Reference: 나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까. 그냥 거기는 쫌 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# --------------------------------------------------
# Processing: KsponSpeech_592002.wav
# CER: 0.0000
# Transcription:  발 뺀 거지?
# Reference: 발 뺀 거지?
# --------------------------------------------------
# Processing: KsponSpeech_555828.wav
# CER: 0.1667
# Transcription:  나는? 나는 내 여수집 안에 알바가야 되잖아. 오늘 처음 가잖아.
# Reference: 나는? 나는 나 여섯 시 반에 알바 가야 되잖아. 오늘 처음 가잖아.
# --------------------------------------------------
# Processing: KsponSpeech_544438.wav
# CER: 0.0000
# Transcription:  음
# Reference: 음.
# --------------------------------------------------
# Processing: KsponSpeech_619033.wav
# CER: 0.4167
# Transcription:  오니오 전복맛 전복맛 전복스
# Reference: 아니야. 전복만. 전복만. 전복쓰
# --------------------------------------------------
# Processing: KsponSpeech_549073.wav
# CER: 0.1111
# Transcription:  역배를 하면 커지지
# Reference: 역배를 하면은 커지지.
# --------------------------------------------------
# Processing: KsponSpeech_595616.wav
# CER: 0.2373
# Transcription:  아, 아이를 안 좋아하면 사실 힘들지. 애들... 다르... 애들 TMI 얘기하는 거 보면... 그게 너무 싫구나. 나는 좀 귀엽다고 얘기할 게 있는데. 싫구나.
# Reference: 근데 아 아일 안 좋아하면 사실 힘들지. 애들 다루 근데 애들 tmi 얘기하는 거 보면 아 그게 너무 싫구나? 나는 좀 귀엽다고 얘기할려 그랬는데. 싫구나.
# --------------------------------------------------
# Processing: KsponSpeech_529406.wav
# CER: 0.1667
# Transcription:  난리나. 본인이 말하고 싶어 못 참아해.
# Reference: 금 난리 나. 본인이 말하고 싶어 갖고 못 참아 해.
# --------------------------------------------------
# Processing: KsponSpeech_536673.wav
# CER: 0.3000
# Transcription:  진짜 막 찬인하게 잘 뼈서 해가지고 그러니까 막 찬인한 장면에는 안 나오는데 깜놀도 좀 있고
# Reference: 막 어 진짜 막 잔인하게 잘 묘사해가지고 그니까 막 잔인한 장면은 안 나오는데 어 깜놀도 쫌 있구.
# --------------------------------------------------
# Processing: KsponSpeech_531484.wav
# CER: 0.1616
# Transcription:  아침에? 아침에 보통 다르지 내가 학원을 갈 때 이거 안 갈 때 있으니까 월수금 같은 경우는 학원을 내가 다니니까 좀 평소에 일찍 일어나고 그렇지 않을 때는 화목 같은 경우는 그냥 내 일어나고 싶은 날 일어나는 그런 시기죠 너는
# Reference: 응. 아침에? 아침에 이제 보통 다르지. 내가 학원을 갈 때가 있고 안 갈 때 있으니까. 월 수 금 같은 경우는 학원을 내가 다니니까 좀 평소보다 일찍 일어나고 이제 그렇지 않을 때는 화 목 같은 경우는 그냥 내가 일어나고 싶은 날 일어 일어나는 그런 식이지. 너는?
# --------------------------------------------------
# Processing: KsponSpeech_550925.wav
# CER: 0.1250
# Transcription:  나는... 나는 두 번인가 3번 봤는데? 나는 언제 그렇게 봤지?
# Reference: 나는 나는 나는 두 번인가 세 번 봤는데? 나는 언제 그렇게 봤지?
# --------------------------------------------------
# Processing: KsponSpeech_568561.wav
# CER: 0.0455
# Transcription:  그거 오래 됐어 나는 보통 그거 한 달 쓰거든. 그 헤어팩.
# Reference: 그거 오래됐어. 나는 보통 그거 한 한 달 쓰거든 그 헤어 팩
# --------------------------------------------------
# Processing: KsponSpeech_594468.wav
# CER: 0.0000
# Transcription:  웃기네
# Reference: 웃기네.
# --------------------------------------------------
# Processing: KsponSpeech_564413.wav
# CER: 0.3571
# Transcription:  그런 후는 그런 모습은 찾을 수가 없고 진짜 현실이 낫는데
# Reference: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실 남맨데
# --------------------------------------------------
# Processing: KsponSpeech_544813.wav
# CER: 0.1250
# Transcription:  마우스 샀잖아. 아 마우스는 원래 있거든.
# Reference: 마우스 샀잖아 아 마우스는 원래 있구.
# --------------------------------------------------
# Processing: KsponSpeech_586007.wav
# CER: 0.6250
# Transcription:  물 안 굴에 붙어 할걸?
# Reference: 물 아 구래? 못할걸?
# --------------------------------------------------
# Processing: KsponSpeech_515652.wav
# CER: 0.0000
# Transcription:  아 진짜로?
# Reference: 아 진짜로?
# --------------------------------------------------
# Processing: KsponSpeech_509494.wav
# CER: 0.0000
# Transcription:  그치? 정말...
# Reference: 그치 정말.
# --------------------------------------------------
# Processing: KsponSpeech_622439.wav
# CER: 0.0000
# Transcription:  어, 있어 그런 거
# Reference: 어. 있어 그런 거.
# --------------------------------------------------
# Processing: KsponSpeech_523022.wav
# CER: 0.6000
# Transcription:  저기 헤어여
# Reference: 저기 혜화역
# --------------------------------------------------
# Processing: KsponSpeech_517134.wav
# CER: 0.2833
# Transcription:  그냥 모든 게 다 그런 거야 지금 상황이 저러니까 모든 게 또 자식도 잘못한 것도 있지만 내일 저를 잘 못하고 있나 그런 생각도 있고
# Reference: 그니까 그냥 모든 게 다 그런 거야 지금 상황 형 상황이 요러니까. 어뜨케 보면 또 자식도 뭐 잘못한 것도 있지만. 뭐 내조를 잘못하고 있나? 그런 생각도 있.
# --------------------------------------------------
# Processing: KsponSpeech_602446.wav
# CER: 0.0769
# Transcription:  그러니까 최근 말고 좀 덜 최근, 그러니까 내 신시험 할 때쯤에 최근?
# Reference: 그니까 최근 말고 좀 덜 최근 그니까 내신 시험할 때쯤에 최근
# --------------------------------------------------
# Processing: KsponSpeech_531126.wav
# CER: 0.5517
# Transcription:  다 소시이나 6시까지 했지? 원래 9.5이잖아 그래서
# Reference: 다섯 시나 여 여섯 시까지겠지? 원래 nine to five잖아 그래서.
# --------------------------------------------------
# Processing: KsponSpeech_566911.wav
# CER: 0.1579
# Transcription:  중국에서 우연히 중국 사람들이 그 돌로
# Reference: 근데 중국에서 우연히 중국 사람들이 그 돌로 뭐.
# --------------------------------------------------
# Processing: KsponSpeech_578097.wav
# CER: 0.1818
# Transcription:  여성 증병이라 그 새 근데 그런 것들이 진행이 되려면은
# Reference: 여성 징병이라 글쎄 근데 그런 것들이 진행이 될려면은
# --------------------------------------------------
# Processing: KsponSpeech_585961.wav
# CER: 0.0909
# Transcription:  심리가 비슷하다 하는 거지.
# Reference: 심리가 비슷하다는 거지?
# --------------------------------------------------
# Processing: KsponSpeech_601933.wav
# CER: 0.3636
# Transcription:  어쨌든 젓가락이 먹어야지
# Reference: 어쨌든 적당히 먹어야지.
# --------------------------------------------------
# Processing: KsponSpeech_593839.wav
# CER: 0.5833
# Transcription:  다른 잘 만드라고? 다 입어봤고
# Reference: 나랑 잘 맞더라고. 다 A 맞고.
# --------------------------------------------------
# Processing: KsponSpeech_496960.wav
# CER: 0.2353
# Transcription:  온통 쏠릴 것 같아서 3D를 선뜻 못하게 했어서 포장도 그렇게 많은 그걸로 아닌데
# Reference: 온통 쏠릴 거 같아서 쓰리디를 선뜻 못하겠 겠어서 포장도 그렇게 많은 그거는 아닌데.
# --------------------------------------------------
# Processing: KsponSpeech_521636.wav
# CER: 0.3607
# Transcription:  빨리 시작을 해야지 그게 빨리 싸여서 경력이 싸으니까 조금 있다가 하면 나중에 다 까먹고 이러면 그게 안 되니까
# Reference: 왜냐면 빨리 따야 빨리해 시작을 해야지 그게 빨리 쌓여 쌓여가지고 경력이 쌓이니까. 이게 조금 이따가 하면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# --------------------------------------------------
# Processing: KsponSpeech_577689.wav
# CER: 0.2000
# Transcription:  어, 누나는 집에 없지 결혼했지 집에 없게 근데 가끔 누나가서 도와주도 있는데
# Reference: 어. 커 아 누나는 이제 집에 없지. 결혼 했지. 집에 없 근데 가끔 누나 가서 도와줄 수 있는데
# --------------------------------------------------
# Processing: KsponSpeech_608974.wav
# CER: 0.0182
# Transcription:  남자친구가 없어 하면은 굉장히 어머니가 불안해 하더라고 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해 하시고 했는데
# Reference: 남자 친구가 없어 하면은 굉장히 그 어머니가 불안해하더라고. 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데
# --------------------------------------------------
# Processing: KsponSpeech_609729.wav
# CER: 0.1852
# Transcription:  근데 나는 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 것 같아
# Reference: 데 난 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 거 같애
# --------------------------------------------------
# Processing: KsponSpeech_573323.wav
# CER: 0.1154
# Transcription:  그래서 내가 신경 치료까지 했단 말이에요. 신경이 죽어가지고
# Reference: 그래서 내가 그 신경 치료까지 했단 말이야. 신경이 죽어가지고.
# --------------------------------------------------
# Processing: KsponSpeech_610233.wav
# CER: 0.1000
# Transcription:  그러니까 그 생각하니까
# Reference: 그니까 그 생각하니까.
# --------------------------------------------------
# Processing: KsponSpeech_574615.wav
# CER: 0.5172
# Transcription:  이 각버는 10% 가산점을 주니까 90% 100분이 맞는 얘들도
# Reference: 이과 꺼는 이제 십 프로 가산점을 주니까 어 구십 프로 백분위 맡는 얘들도
# --------------------------------------------------
# Processing: KsponSpeech_510618.wav
# CER: 0.3571
# Transcription:  132명 뽑는데 컷 점수가 내 점수야 컷 점수가 그러니까 나랑 동점자가 꿀찜거야
# Reference: 완전 아니 백 삼십 이 명 뽑는데 컷 점수가 백 배 내 점수야 컷 점수가 그니까 나랑 동점자가 이제 꼴진 거야
# --------------------------------------------------
# Processing: KsponSpeech_576594.wav
# CER: 0.2778
# Transcription:  그런 데가 있구나. 니가 가져간 데가 고개야.
# Reference: 그런 데가 있구나 니가 가자고 한데가 거기야?
# --------------------------------------------------
# Processing: KsponSpeech_542633.wav
# CER: 0.2778
# Transcription:  아빠 50살된다 했던 게 없을 것 같은데 진짜
# Reference: 아빠 오십 살 된다 했던 게 엊그제 같은데 진짜.
# --------------------------------------------------
# Processing: KsponSpeech_588225.wav
# CER: 0.1942
# Transcription:  그런 거? 그때마다 이렇게 너희도 안 넣어준 건 아니거든 너희도 넣어줬는데 좀 좀 내가 느끼기에는 얘가 나를 생각해서 사오라기보다는 집에 남는 거 있잖아 뭔가 엄마가 사오셨는데 집에 쟁여두고 있다가 하나씩 갔다가 나를 주는 거 같은
# Reference: 고런 거? 그때마다 걔가 이렇게 뭘 넣어주는 안 넣어준 건 아니거든? 넣어주긴 넣어줬는데 쫌 쫌 내가 느끼기에는 얘가 나를 생각해서 사 온 거라기보다는 집에 남는 거 있잖아? 뭔가 엄마가 사 오셨는데 집에 이렇게 쟁여두고 있다가 하나씩 갖다가 나를 주는 거 같은.
# --------------------------------------------------
# Processing: KsponSpeech_517345.wav
# CER: 0.1714
# Transcription:  아 내 생각에는 안경 때문에 좀 걸쳐지는 게 불편했나? 근데 너 안경 못으니까 단 사람 같아
# Reference: 아 내 생각엔 안경 땜에 좀 걸쳐지는 게 불편했나? 근데 너 안경 벗으니까 딴 사람 같아.
# --------------------------------------------------
# Processing: KsponSpeech_617232.wav
# CER: 0.0000
# Transcription:  자기가 너무 크니까
# Reference: 자기가 너무 크니까.
# --------------------------------------------------
# Processing: KsponSpeech_527157.wav
# CER: 0.2000
# Transcription:  그럴 것 같지? 우리 다음 주부터 둘 다 출근할 것 같으니까 주말은 넘어니까 금요일?
# Reference: 그럴 거 같지? 우리 다음 주부터 둘 다 출근할 거 같으니까. 주말 주말은 너무하니까 금요일?
# --------------------------------------------------
# Processing: KsponSpeech_561775.wav
# CER: 0.3529
# Transcription:  그러니까 탄산업년만 먹고 싶을 때 있잖아
# Reference: 이까 탄산음료 먹고 싶을 때 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_551757.wav
# CER: 0.1765
# Transcription:  그냥 나오고 혼자 그렇게 생각하는 건데.
# Reference: 군 그냥 나 혼자 그렇게 생각하는 건데?
# --------------------------------------------------
# Processing: KsponSpeech_605994.wav
# CER: 0.1667
# Transcription:  다 공부해야 돼
# Reference: 나 공부해야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_502392.wav
# CER: 0.2222
# Transcription:  근데 약간 오리오빠들은 그거 잘해. 자기 혼자 영어폭북 마케팅 다해.
# Reference: 근데 약간 우리 오빠는 그거 잘해. 자기 혼자 영업 홍보 마케팅 다 해.
# --------------------------------------------------
# Processing: KsponSpeech_573125.wav
# CER: 0.3636
# Transcription:  받은 거예요 엄마한테?
# Reference: o. 아 받은 거여. 엄마한테?
# --------------------------------------------------
# Processing: KsponSpeech_611873.wav
# CER: 0.1224
# Transcription:  헤리포터 영화 자체가 전체에 다 영국인이고 거기서 나오는 동양인이라도 영국에 사는 사람이고 그래서 되게 사람들이
# Reference: 그 해리포터 영화 자체가 전체 다 영국인이고 거기서 나오는 동양인이라도 영국에 사는 사람이고 계속되게 사람들이
# --------------------------------------------------
# Processing: KsponSpeech_549930.wav
# CER: 0.4643
# Transcription:  살건 아니고 그냥 혼자서 아이소빙을 하면서 호기나 눈에 띄는 게 있다면, 특히 말하고 가는 거지.
# Reference: 살 건 아니고 그냥 혼자서 아이 쇼핑을 하면서 혹이나 눈에 띄는 게 있다면 득템하러 가는 거지. 꾿이 내가 뭘 살려고 가는 것은 아니다 그런 거지.
# --------------------------------------------------
# Processing: KsponSpeech_584024.wav
# CER: 1.0000
# Transcription:  먹었을까 나 하자
# Reference: 모가 수위가 낮아.
# --------------------------------------------------
# Processing: KsponSpeech_514225.wav
# CER: 0.3889
# Transcription:  첫 번째 연대에 못 가고 다음 연대였어.
# Reference: 그 첫 번째 년도에 못 가고 그 다음 연도에 갔어.
# --------------------------------------------------
# Processing: KsponSpeech_539926.wav
# CER: 0.0000
# Transcription:  그래 빨리 보내줘
# Reference: 그래 빨리 보내줘
# --------------------------------------------------
# Processing: KsponSpeech_540647.wav
# CER: 0.3333
# Transcription:  또는 여행한가?
# Reference: 너는 여행 안 가?
# --------------------------------------------------
# Processing: KsponSpeech_505546.wav
# CER: 0.1667
# Transcription:  병인이라는 사람이 이하킷됐잖아 너무 놀고 돈만 먹고 놀고 있는 거야
# Reference: 그 병인이라는 사람이 이 학기 때 했잖아. 너무 놀고 돈만 먹고 놀고 있는 거야.
# --------------------------------------------------
# Processing: KsponSpeech_510540.wav
# CER: 1.0000
# Transcription:  끝이
# Reference: 그치.
# --------------------------------------------------
# Processing: KsponSpeech_574951.wav
# CER: 0.3793
# Transcription:  몇 명 정도 있어? 어이기는 나가라겠다고? 그땐 배척당하지 않을까?
# Reference: 몇 명 정도 있어? 어인의 나라가 있다고? 걔네는 약간 배척당하지 않을까?
# --------------------------------------------------
# Processing: KsponSpeech_547184.wav
# CER: 0.3333
# Transcription:  근데 무릎에서 걔가 하는 말이 갖고 싶어서 약간 거부감이 될 때가 있긴 있었어. 통화를 같이 했었으니까.
# Reference: 아 근데 모르겠어. 걔가 하는 말이 가끔씩 쫌 약간 거부감이 들 때가 있긴 있었어. 동아릴 같이했었으니까.
# --------------------------------------------------
# Processing: KsponSpeech_596750.wav
# CER: 0.1765
# Transcription:  그래서 그냥 좀 약간 입고와 입을 담스러워
# Reference: 그래서 그냥 좀 약간 입고 가기 부담스러워.
# --------------------------------------------------
# Processing: KsponSpeech_529908.wav
# CER: 0.5000
# Transcription:  이제 다 싱크를
# Reference: 에 다 싱크홀.
# --------------------------------------------------
# Processing: KsponSpeech_612661.wav
# CER: 0.2381
# Transcription:  너무 아깝더라. 누가랑 같이 보는데. 재밌는 곳이 없고.
# Reference: 너무 아깝더라. 누나랑 같이 보는데 재미도 없고
# --------------------------------------------------
# Processing: KsponSpeech_615557.wav
# CER: 0.1111
# Transcription:  홍보고대사 같은 거 아니면 내가 알기로는...
# Reference: 그 홍보대사 같은 거 아니면 내가 알기로는.
# --------------------------------------------------
# Processing: KsponSpeech_536215.wav
# CER: 0.3043
# Transcription:  한시 반까지만 마시면 되지. 그때가 이제 소리 있잖아.
# Reference: 한 한 시 반까지만 마시면 되지. 그때까진 지하철이 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_593491.wav
# CER: 0.0952
# Transcription:  올 땐 데리러 올거야 아니면 인정공화에서 만나던가
# Reference: 올 땐 데리러 올 거야 아니면 인천공항에서 만나던가.
# --------------------------------------------------
# Processing: KsponSpeech_520848.wav
# CER: 0.1250
# Transcription:  치즈 한 박스테이크?
# Reference: 치즈 함박 스테이크?
# --------------------------------------------------
# Processing: KsponSpeech_585460.wav
# CER: 0.1667
# Transcription:  갔다? 언제 갔다 왔어 옛날에 갔다 오구나
# Reference: 갔다 온. 너 언제 갔다 왔어. 옛날에 갔다 왔구나.
# --------------------------------------------------
# Processing: KsponSpeech_611985.wav
# CER: 0.7500
# Transcription:  고, 그렇지?
# Reference: 어 그치.
# --------------------------------------------------
# Processing: KsponSpeech_509670.wav
# CER: 0.6667
# Transcription:  청소는 좀 싸
# Reference: 청소년으로 보내 줌 싸.
# --------------------------------------------------
# Processing: KsponSpeech_592064.wav
# CER: 0.2000
# Transcription:  눈이 상태가 어떤지 계속 봐야 되는데
# Reference: 눈이 상태가 어떤지 계속 봐야 된대.
# --------------------------------------------------
# Processing: KsponSpeech_509147.wav
# CER: 0.4062
# Transcription:  수능 봤는데 최소였거든 최소였는데 그 독성여 된 거 거기 논소리로 잡혔대
# Reference: 수능 봤는데 재수했거든? 재수했는데 그 덕성여대인가? 거기 논술로 잡혔대 어
# --------------------------------------------------
# Processing: KsponSpeech_608811.wav
# CER: 0.3000
# Transcription:  그리고 저번에 저번 달인가? 몇 주 전에 고축 스카이더면서 하는 숙제가 하지 않았어?
# Reference: 그리고 우리 저번 이번에도 저번 달인가 몇 주 전에 고척스카이돔에서 하는 축 그 축제 가지 않았어?
# --------------------------------------------------
# Processing: KsponSpeech_573353.wav
# CER: 0.0000
# Transcription:  그.. 시간 동안 내가 하고 싶은 걸 좀 하다가 이제..
# Reference: 그 시간 동안 내가 하고 싶은 걸 좀 하다가 이제.
# --------------------------------------------------
# Processing: KsponSpeech_586029.wav
# CER: 0.3077
# Transcription:  우리 지금 하루 다음 일곱 만났어
# Reference: 우리 지금 하루 텀 있고 만났어.
# --------------------------------------------------
# Processing: KsponSpeech_563030.wav
# CER: 0.3333
# Transcription:  보니까 뇌발근은 둔 내는 거였어?
# Reference: 보니까? 연애에 발견은? 돈 내는 거였어?
# --------------------------------------------------
# Processing: KsponSpeech_538803.wav
# CER: 0.1429
# Transcription:  빼방이지 이러면
# Reference: 빼박이지 이러면.
# --------------------------------------------------
# Processing: KsponSpeech_512824.wav
# CER: 0.2500
# Transcription:  과형이랑 승원이랑
# Reference: 가영이랑 승원이랑
# --------------------------------------------------
# Processing: KsponSpeech_575385.wav
# CER: 0.0976
# Transcription:  강식당하면 이번에는 더 재밌을 것 같다. 피오 있어서 피오가 강식당. 이번에 좀 톡톡히 할 것 같은데. 그쵸.
# Reference: 강 식당 하면 이번에는 더 재밌을 거 같다. 피오 있어서 피오가 강 식당 이번에 쫌 톡톡히 할 거 같은데. 그체.
# --------------------------------------------------
# Processing: KsponSpeech_600850.wav
# CER: 0.2353
# Transcription:  주말 수당은 저도 야근 수당 안 주는데 많지
# Reference: 주말 수당은 줘도 야근 수당 안 준 데는 많지.
# --------------------------------------------------
# Processing: KsponSpeech_574095.wav
# CER: 0.1500
# Transcription:  아 이번엔 내 친구 병살 공무원 준비하는데 붙었다?
# Reference: 아 이번에 내 친구 경찰공무원 준비하는데 붙었다.
# --------------------------------------------------
# Processing: KsponSpeech_576092.wav
# CER: 0.1667
# Transcription:  큰 날만이구나.
# Reference: 근 날만이구나.
# --------------------------------------------------
#
# Average CER: 0.2462

# %%
import requests
import os
import json
import librosa
import torch
import random
import nlptutti as metrics


class ClovaSpeechClient:
    # Clova Speech invoke URL (앱 등록 시 발급받은 Invoke URL)
    invoke_url = 'Your URL'
    # Clova Speech secret key (앱 등록 시 발급받은 Secret Key)
    secret = 'Your KEY'

    def req_url(self, url, completion, callback=None, userdata=None, forbiddens=None, boostings=None, wordAlignment=True, fullText=True, diarization=None, sed=None):
        request_body = {
            'url': url,
            'language': 'ko-KR',
            'completion': completion,
            'callback': callback,
            'userdata': userdata,
            'wordAlignment': wordAlignment,
            'fullText': fullText,
            'forbiddens': forbiddens,
            'boostings': boostings,
            'diarization': diarization,
            'sed': sed,
        }
        headers = {
            'Accept': 'application/json;UTF-8',
            'Content-Type': 'application/json;UTF-8',
            'X-CLOVASPEECH-API-KEY': self.secret
        }
        return requests.post(headers=headers,
                             url=self.invoke_url + '/recognizer/url',
                             data=json.dumps(request_body).encode('UTF-8'))

    def req_object_storage(self, data_key, completion, callback=None, userdata=None, forbiddens=None, boostings=None,
                           wordAlignment=True, fullText=True, diarization=None, sed=None):
        request_body = {
            'dataKey': data_key,
            'language': 'ko-KR',
            'completion': completion,
            'callback': callback,
            'userdata': userdata,
            'wordAlignment': wordAlignment,
            'fullText': fullText,
            'forbiddens': forbiddens,
            'boostings': boostings,
            'diarization': diarization,
            'sed': sed,
        }
        headers = {
            'Accept': 'application/json;UTF-8',
            'Content-Type': 'application/json;UTF-8',
            'X-CLOVASPEECH-API-KEY': self.secret
        }
        return requests.post(headers=headers,
                             url=self.invoke_url + '/recognizer/object-storage',
                             data=json.dumps(request_body).encode('UTF-8'))

    def req_upload(self, file, completion, callback=None, userdata=None, forbiddens=None, boostings=None,
                   wordAlignment=True, fullText=True, diarization=None, sed=None):
        request_body = {
            'language': 'ko-KR',
            'completion': completion,
            'callback': callback,
            'userdata': userdata,
            'wordAlignment': wordAlignment,
            'fullText': fullText,
            'forbiddens': forbiddens,
            'boostings': boostings,
            'diarization': diarization,
            'sed': sed,
        }
        headers = {
            'Accept': 'application/json;UTF-8',
            'X-CLOVASPEECH-API-KEY': self.secret
        }
        # print(json.dumps(request_body, ensure_ascii=False).encode('UTF-8'))
        files = {
            'media': open(file, 'rb'),
            'params': (None, json.dumps(request_body, ensure_ascii=False).encode('UTF-8'), 'application/json')
        }
        response = requests.post(headers=headers, url=self.invoke_url + '/recognizer/upload', files=files)
        return response

if __name__ == '__main__':
    # res = ClovaSpeechClient().req_url(url='http://example.com/media.mp3', completion='sync')
    # res = ClovaSpeechClient().req_object_storage(data_key='data/media.mp3', completion='sync')
    # res = ClovaSpeechClient().req_upload(file='/content/09711-F-84-JA-A-LAR009-2243546.wav', completion='sync')
    # print(res.text)

    random.seed(42)

    # 변환할 음성 파일 경로 설정
    audio_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech원본"
    json_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech정답"

    # 모든 WAV 파일 목록 가져오기
    all_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
    selected_files = random.sample(all_files, min(100, len(all_files)))

    cer_list = []

    for file_name in selected_files:
      file_path = os.path.join(audio_folder, file_name)
      json_path = os.path.join(json_folder, file_name.replace(".wav", ".txt"))

      print(f"Processing: {file_name}")

      res = ClovaSpeechClient().req_upload(file=file_path, completion='sync')
      res_json = json.loads(res.text)
      asr_text = res_json['text']

      if os.path.exists(json_path):
          with open(json_path, "r", encoding="utf-8") as f:
              data = f.read().strip()

              cer_result = metrics.get_cer(data, asr_text)
              cer = cer_result['cer']
              cer_list.append(cer)
              print(f"CER: {cer:.4f}")
      else:
          print("No reference text found.")

      print(f"Transcription: {asr_text}")
      print(f"Reference: {data}")
      print("-" * 50)

    if cer_list:
        print(f"\nAverage CER: {sum(cer_list)/len(cer_list):.4f}")
# Out:
# Processing: KsponSpeech_539357.wav
# CER: 0.0833
# Transcription: 나는 어제 네 표정 보고 알았어 쟤는 진짜 사기 싫어하는구나.
# Reference: 나는 어제 니 표정 보고 알았어. 쟤는 진짜 타기 싫어하는구나.
# --------------------------------------------------
# Processing: KsponSpeech_608138.wav
# CER: 0.0556
# Transcription: 그 제목 뭐였지 우리들의 월급은 정당한가.
# Reference: 그 제목 뭐였지? 우리들의 월급은 정 정당한가?
# --------------------------------------------------
# Processing: KsponSpeech_618809.wav
# CER: 0.0476
# Transcription: 내 친구의 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비싼 데가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑.
# Reference: 그 내 친구에 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비 비싼 데가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑
# --------------------------------------------------
# Processing: KsponSpeech_524718.wav
# CER: 0.4000
# Transcription: 추천 많이 해서.
# Reference: 응. 그거는 추천 많이 해서
# --------------------------------------------------
# Processing: KsponSpeech_585605.wav
# CER: 0.0000
# Transcription: 찹쌀탕수육.
# Reference: 찹쌀탕수육.
# --------------------------------------------------
# Processing: KsponSpeech_589709.wav
# CER: 0.0000
# Transcription: 되게 연기 잘하잖아.
# Reference: 되게 연기 잘하잖아.
# --------------------------------------------------
# Processing: KsponSpeech_592791.wav
# CER: 0.3333
# Transcription: 수응이 아니라 수응이.
# Reference: 수응이 알아? 수응이
# --------------------------------------------------
# Processing: KsponSpeech_603838.wav
# CER: 0.1304
# Transcription: 이렇게 좀 행사도 많고 좀 성수기인가 봐 나름 그래서.
# Reference: 이렇게 좀 행사도 많고 좀 성수기인가 봐. 나름 그래가지구
# --------------------------------------------------
# Processing: KsponSpeech_526034.wav
# CER: 0.0139
# Transcription: 시험 보고 들어오라. 그래 시험 보고 들어오라. 그래 형도 시험 보고 들어와야 돼. 내가 볼 거야. 내가 볼 거야. 내가 심사할 거야. 면접도 봐야겠다. 면접도 봐야겠다. 기초 소양 평가 해가지고.
# Reference: 시험 보고 들어오라 그래 시험 보고 들어오라 그래. 경도 시험 보고 들어와야 돼. 내가 볼 거야 내가 볼 거야 내가 심사할 거야 면접도 봐야겠다 면접도 봐야겠다 기초소양 평가해가지고
# --------------------------------------------------
# Processing: KsponSpeech_608909.wav
# CER: 0.0000
# Transcription: 어차피 매출이 얼마가 나오든 물론 나랑은 상관이 없지만 어차피 난 똑같이 돈 받으니까.
# Reference: 어차피 매출이 얼마가 나오든 물론 나랑은 상관이 없지만. 어차피 난 똑같이 돈 받으니까.
# --------------------------------------------------
# Processing: KsponSpeech_534277.wav
# CER: 0.0000
# Transcription: 아니야 애증은 아니야.
# Reference: 아니야 애증은 아니야.
# --------------------------------------------------
# Processing: KsponSpeech_524663.wav
# CER: 0.0000
# Transcription: 맞아.
# Reference: 맞아.
# --------------------------------------------------
# Processing: KsponSpeech_506541.wav
# CER: 0.0000
# Transcription: 근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까.
# Reference: 근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까
# --------------------------------------------------
# Processing: KsponSpeech_550994.wav
# CER: 0.1176
# Transcription: 잘했어 그럼 이제 배워볼 생각은 없어.
# Reference: 으음 잘했어. 그럼 이제 배워 볼 생각은 없어?
# --------------------------------------------------
# Processing: KsponSpeech_610899.wav
# CER: 0.0000
# Transcription: 얼마나 신선했으면 애벌레가 나왔니.
# Reference: 얼마나 신선했으면 애벌레가 나왔니
# --------------------------------------------------
# Processing: KsponSpeech_544963.wav
# CER: 0.0000
# Transcription: 아까 무슨 얘기하고 있었지.
# Reference: 아까 무슨 얘기하고 있었지.
# --------------------------------------------------
# Processing: KsponSpeech_566814.wav
# CER: 0.0000
# Transcription: 네 말씀하세요.
# Reference: 네. 말씀하세요.
# --------------------------------------------------
# Processing: KsponSpeech_617728.wav
# CER: 0.0000
# Transcription: 좀 들어가야 돼.
# Reference: 좀 들어가야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_619452.wav
# CER: 0.0833
# Transcription: 나는 근데 생각보다 늦게 좋아해가지고 수능 끝나고 피 담는 물 나와서 그때부터 좋아했어.
# Reference: 나는 근데 생각보다 늦게 좋아해가지구 수능 끝나고 피 땀 눈물 나와서 그때부터 좋아했어.
# --------------------------------------------------
# Processing: KsponSpeech_609816.wav
# CER: 0.0000
# Transcription: 근데 나는 이번에 좀 열심히 해볼게 그러면 끊으면 만약에.
# Reference: 근데 나는 이번에 좀 열심히 해 볼게 그러면. 끊으면 만약에
# --------------------------------------------------
# Processing: KsponSpeech_594199.wav
# CER: 0.0385
# Transcription: 나는 근무를 하고 싶고 애초에 뭔가 거기 가서 살 생각까지 있으니까 그냥 거기는 좀 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# Reference: 나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까. 그냥 거기는 쫌 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# --------------------------------------------------
# Processing: KsponSpeech_592002.wav
# CER: 0.0000
# Transcription: 발 뺀 거지.
# Reference: 발 뺀 거지?
# --------------------------------------------------
# Processing: KsponSpeech_555828.wav
# CER: 0.1250
# Transcription: 나는 나는 내가 6시 반에 알바 가야 되잖아 오늘 처음 가잖아.
# Reference: 나는? 나는 나 여섯 시 반에 알바 가야 되잖아. 오늘 처음 가잖아.
# --------------------------------------------------
# Processing: KsponSpeech_544438.wav
# CER: 1.0000
# Transcription: 응.
# Reference: 음.
# --------------------------------------------------
# Processing: KsponSpeech_619033.wav
# CER: 0.3333
# Transcription: 아니요 전복 맛 전복 맛 전복.
# Reference: 아니야. 전복만. 전복만. 전복쓰
# --------------------------------------------------
# Processing: KsponSpeech_549073.wav
# CER: 0.1111
# Transcription: 역배를 하면 커지지.
# Reference: 역배를 하면은 커지지.
# --------------------------------------------------
# Processing: KsponSpeech_595616.wav
# CER: 0.1525
# Transcription: 근데 아이를 안 좋아하면 사실 힘들지. 애들 다루기 애들 TMI 얘기하는 거 보면 그게 너무 싫구나. 나는 좀 귀엽다고 얘기할래 그랬는데 싫구나.
# Reference: 근데 아 아일 안 좋아하면 사실 힘들지. 애들 다루 근데 애들 tmi 얘기하는 거 보면 아 그게 너무 싫구나? 나는 좀 귀엽다고 얘기할려 그랬는데. 싫구나.
# --------------------------------------------------
# Processing: KsponSpeech_529406.wav
# CER: 0.2222
# Transcription: 난리 나 본인이 말하고 싶어 못 참아요.
# Reference: 금 난리 나. 본인이 말하고 싶어 갖고 못 참아 해.
# --------------------------------------------------
# Processing: KsponSpeech_536673.wav
# CER: 0.2051
# Transcription: 진짜 막 잔인하게 잘 묘사해가지고 그러니까 막 잔인한 장면은 안 나오는데 감물도 좀 있고.
# Reference: 막 어 진짜 막 잔인하게 잘 묘사해가지고 그니까 막 잔인한 장면은 안 나오는데 어 깜놀도 쫌 있구.
# --------------------------------------------------
# Processing: KsponSpeech_531484.wav
# CER: 0.0700
# Transcription: 아침에 이제 보통 다르지 내가 학원을 갈 때가 있고 안 갈 때가 있으니까 월수금 같은 경우는 학원을 내가 다니니까 좀 평소보다 일찍 일어나고 이제 그렇지 않을 때는 화목 같은 경우는 그냥 내가 일어나고 싶은 날 일어나는 그런 식이지 너는.
# Reference: 응. 아침에? 아침에 이제 보통 다르지. 내가 학원을 갈 때가 있고 안 갈 때 있으니까. 월 수 금 같은 경우는 학원을 내가 다니니까 좀 평소보다 일찍 일어나고 이제 그렇지 않을 때는 화 목 같은 경우는 그냥 내가 일어나고 싶은 날 일어 일어나는 그런 식이지. 너는?
# --------------------------------------------------
# Processing: KsponSpeech_550925.wav
# CER: 0.0833
# Transcription: 나는 나는 나는 2번인가 3번 봤는데 나는 언제 그렇게 봤지.
# Reference: 나는 나는 나는 두 번인가 세 번 봤는데? 나는 언제 그렇게 봤지?
# --------------------------------------------------
# Processing: KsponSpeech_568561.wav
# CER: 0.0000
# Transcription: 그거 오래 됐어. 나는 보통 그거 한 한 달 쓰거든. 그 헤어팩.
# Reference: 그거 오래됐어. 나는 보통 그거 한 한 달 쓰거든 그 헤어 팩
# --------------------------------------------------
# Processing: KsponSpeech_594468.wav
# CER: 0.0000
# Transcription: 웃기네.
# Reference: 웃기네.
# --------------------------------------------------
# Processing: KsponSpeech_564413.wav
# CER: 0.0714
# Transcription: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실 남매인데.
# Reference: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실 남맨데
# --------------------------------------------------
# Processing: KsponSpeech_544813.wav
# CER: 0.1875
# Transcription: 마우스 샀잖아 마우스는 원래 있거나.
# Reference: 마우스 샀잖아 아 마우스는 원래 있구.
# --------------------------------------------------
# Processing: KsponSpeech_586007.wav
# CER: 0.4286
# Transcription: 그래 못 할 걸.
# Reference: 물 아 구래? 못할걸?
# --------------------------------------------------
# Processing: KsponSpeech_515652.wav
# CER: 0.2500
# Transcription: 진짜로.
# Reference: 아 진짜로?
# --------------------------------------------------
# Processing: KsponSpeech_509494.wav
# CER: 0.4000
# Transcription: 그렇지 정말.
# Reference: 그치 정말.
# --------------------------------------------------
# Processing: KsponSpeech_622439.wav
# CER: 0.0000
# Transcription: 어 있어 그런 거.
# Reference: 어. 있어 그런 거.
# --------------------------------------------------
# Processing: KsponSpeech_523022.wav
# CER: 0.0000
# Transcription: 저기 혜화역.
# Reference: 저기 혜화역
# --------------------------------------------------
# Processing: KsponSpeech_517134.wav
# CER: 0.1639
# Transcription: 그러니까 그냥 모든 게 다 그런 거야. 지금 상황이 저러니까 어떻게 보면 또 자식도 뭐 잘못한 것도 있지만 뇌조를 잘 못하고 있나 그런 생각도 있고.
# Reference: 그니까 그냥 모든 게 다 그런 거야 지금 상황 형 상황이 요러니까. 어뜨케 보면 또 자식도 뭐 잘못한 것도 있지만. 뭐 내조를 잘못하고 있나? 그런 생각도 있.
# --------------------------------------------------
# Processing: KsponSpeech_602446.wav
# CER: 0.0769
# Transcription: 그러니까 최근 말고 좀 덜 최근 그러니까 내신 시험 할 때쯤에 최근.
# Reference: 그니까 최근 말고 좀 덜 최근 그니까 내신 시험할 때쯤에 최근
# --------------------------------------------------
# Processing: KsponSpeech_531126.wav
# CER: 0.5172
# Transcription: 5시나 6시까지겠지 원래 나인 2 5잖아 그래서.
# Reference: 다섯 시나 여 여섯 시까지겠지? 원래 nine to five잖아 그래서.
# --------------------------------------------------
# Processing: KsponSpeech_566911.wav
# CER: 0.0526
# Transcription: 근데 중국에서 우연히 중국 사람들이 그 돌로.
# Reference: 근데 중국에서 우연히 중국 사람들이 그 돌로 뭐.
# --------------------------------------------------
# Processing: KsponSpeech_578097.wav
# CER: 0.0455
# Transcription: 여성 징병이라 글쎄 근데 그런 것들이 진행이 되려면은.
# Reference: 여성 징병이라 글쎄 근데 그런 것들이 진행이 될려면은
# --------------------------------------------------
# Processing: KsponSpeech_585961.wav
# CER: 0.0000
# Transcription: 심리가 비슷하다는 거지.
# Reference: 심리가 비슷하다는 거지?
# --------------------------------------------------
# Processing: KsponSpeech_601933.wav
# CER: 0.0000
# Transcription: 어쨌든 적당히 먹어야지.
# Reference: 어쨌든 적당히 먹어야지.
# --------------------------------------------------
# Processing: KsponSpeech_593839.wav
# CER: 0.1667
# Transcription: 나랑 잘 맞더라고 다 이어 맞고.
# Reference: 나랑 잘 맞더라고. 다 A 맞고.
# --------------------------------------------------
# Processing: KsponSpeech_496960.wav
# CER: 0.2059
# Transcription: 온통 쏠릴 것 같아서 3D를 선뜻 못하겠어서 포장도 그렇게 많은 그건 아닌데.
# Reference: 온통 쏠릴 거 같아서 쓰리디를 선뜻 못하겠 겠어서 포장도 그렇게 많은 그거는 아닌데.
# --------------------------------------------------
# Processing: KsponSpeech_521636.wav
# CER: 0.1967
# Transcription: 왜냐하면 빨리 시작을 해야지 그게 빨리 쌓여가지고 경력이 쌓이니까 조금 있다가 하면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# Reference: 왜냐면 빨리 따야 빨리해 시작을 해야지 그게 빨리 쌓여 쌓여가지고 경력이 쌓이니까. 이게 조금 이따가 하면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# --------------------------------------------------
# Processing: KsponSpeech_577689.wav
# CER: 0.1667
# Transcription: 누나는 이제 집에 없지 결혼했지 집에 없고 근데 가끔 누나가 가서 도와줄 때 있는데.
# Reference: 어. 커 아 누나는 이제 집에 없지. 결혼 했지. 집에 없 근데 가끔 누나 가서 도와줄 수 있는데
# --------------------------------------------------
# Processing: KsponSpeech_608974.wav
# CER: 0.0545
# Transcription: 남자친구가 없어 하면 굉장히 어머니가 불안해하더라고 그래서 예전부터 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데.
# Reference: 남자 친구가 없어 하면은 굉장히 그 어머니가 불안해하더라고. 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데
# --------------------------------------------------
# Processing: KsponSpeech_609729.wav
# CER: 0.1154
# Transcription: 근데 난 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 것 같아.
# Reference: 데 난 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 거 같애
# --------------------------------------------------
# Processing: KsponSpeech_573323.wav
# CER: 0.0400
# Transcription: 그래서 내가 신경 치료까지 했단 말이야 신경이 죽어가지고.
# Reference: 그래서 내가 그 신경 치료까지 했단 말이야. 신경이 죽어가지고.
# --------------------------------------------------
# Processing: KsponSpeech_610233.wav
# CER: 0.1000
# Transcription: 그러니까 그 생각하니까.
# Reference: 그니까 그 생각하니까.
# --------------------------------------------------
# Processing: KsponSpeech_574615.wav
# CER: 0.4138
# Transcription: 이 과거는 이제 10% 가산점을 주니까 90% 100분이 맞는 얘들도.
# Reference: 이과 꺼는 이제 십 프로 가산점을 주니까 어 구십 프로 백분위 맡는 얘들도
# --------------------------------------------------
# Processing: KsponSpeech_510618.wav
# CER: 0.2093
# Transcription: 완전 아니 132명 뽑는데 컷 점수가 내 점수야 컷 점수가 그러니까 나랑 동점자가 이제 꼴찌인 거야.
# Reference: 완전 아니 백 삼십 이 명 뽑는데 컷 점수가 백 배 내 점수야 컷 점수가 그니까 나랑 동점자가 이제 꼴진 거야
# --------------------------------------------------
# Processing: KsponSpeech_576594.wav
# CER: 0.0000
# Transcription: 그런 데가 있구나 니가 가자고 한 데가 거기야.
# Reference: 그런 데가 있구나 니가 가자고 한데가 거기야?
# --------------------------------------------------
# Processing: KsponSpeech_542633.wav
# CER: 0.1111
# Transcription: 아빠 50살 된다 했던 게 엊그제 같은데 진짜.
# Reference: 아빠 오십 살 된다 했던 게 엊그제 같은데 진짜.
# --------------------------------------------------
# Processing: KsponSpeech_588225.wav
# CER: 0.0865
# Transcription: 그런 거 그때마다 걔가 이렇게 뭘 안 넣어준 건 아니거든 넣어주긴 넣어줬는데 좀 좀 내가 느끼기에는 얘가 나를 생각해서 사온 그거라기보다는 집에 남는 거 있잖아. 뭔가 엄마가 사 오셨는데 집에 이렇게 쟁여 두고 있다가 하나씩 갖다가 나를 주는 것 같은.
# Reference: 고런 거? 그때마다 걔가 이렇게 뭘 넣어주는 안 넣어준 건 아니거든? 넣어주긴 넣어줬는데 쫌 쫌 내가 느끼기에는 얘가 나를 생각해서 사 온 거라기보다는 집에 남는 거 있잖아? 뭔가 엄마가 사 오셨는데 집에 이렇게 쟁여두고 있다가 하나씩 갖다가 나를 주는 거 같은.
# --------------------------------------------------
# Processing: KsponSpeech_517345.wav
# CER: 0.0882
# Transcription: 내 생각엔 안경 때문에 좀 걸쳐지는 게 불편했나 근데 너 안경 벗으니까 딴 사람 같아.
# Reference: 아 내 생각엔 안경 땜에 좀 걸쳐지는 게 불편했나? 근데 너 안경 벗으니까 딴 사람 같아.
# --------------------------------------------------
# Processing: KsponSpeech_617232.wav
# CER: 0.0000
# Transcription: 자기가 너무 크니까.
# Reference: 자기가 너무 크니까.
# --------------------------------------------------
# Processing: KsponSpeech_527157.wav
# CER: 0.1429
# Transcription: 그럴 거 같지 우리 다음 주부터 둘 다 출근할 거 같으니까 주말은 너무하니까.
# Reference: 그럴 거 같지? 우리 다음 주부터 둘 다 출근할 거 같으니까. 주말 주말은 너무하니까 금요일?
# --------------------------------------------------
# Processing: KsponSpeech_561775.wav
# CER: 0.1875
# Transcription: 그러니까 탄산음료 먹고 싶을 때 있잖아.
# Reference: 이까 탄산음료 먹고 싶을 때 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_551757.wav
# CER: 0.0667
# Transcription: 그냥 나 혼자 그렇게 생각하는 건데.
# Reference: 군 그냥 나 혼자 그렇게 생각하는 건데?
# --------------------------------------------------
# Processing: KsponSpeech_605994.wav
# CER: 0.0000
# Transcription: 나 공부해야 돼.
# Reference: 나 공부해야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_502392.wav
# CER: 0.0000
# Transcription: 근데 약간 우리 오빠는 그거 잘해 자기 혼자 영업 홍보 마케팅 다 해.
# Reference: 근데 약간 우리 오빠는 그거 잘해. 자기 혼자 영업 홍보 마케팅 다 해.
# --------------------------------------------------
# Processing: KsponSpeech_573125.wav
# CER: 0.3000
# Transcription: 받은 거야 엄마한테.
# Reference: o. 아 받은 거여. 엄마한테?
# --------------------------------------------------
# Processing: KsponSpeech_611873.wav
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bf574488e30d> in <cell line: 0>()
#     111       res = ClovaSpeechClient().req_upload(file=file_path, completion='sync')
#     112       res_json = json.loads(res.text)
# --> 113       asr_text = res_json['text']
#     114
#     115       if os.path.exists(json_path):
#
# KeyError: 'text'

# %%
print("클로바")
print(f"\nAverage CER: {sum(cer_list)/len(cer_list):.4f}")
print(len(cer_list))
# Out:
# 클로바
#
# Average CER: 0.1243
# 68

# %%
# !pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (2.3.0)

# %%
import os
import json
import librosa
import random
import urllib3
import base64
import time
import nlptutti as metrics

random.seed(42)

# 변환할 음성 파일 경로 설정
audio_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech원본"
json_folder = "/content/drive/MyDrive/STTDATA/데이터모음/KoSpeech정답"

# 모든 WAV 파일 목록 가져오기
all_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
selected_files = random.sample(all_files, min(100, len(all_files)))

cer_list = []

openApiURL = "http://aiopen.etri.re.kr:8000/WiseASR/Recognition"
accessKey = "Your KEY"
# audioFilePath = "/content/KsponSpeech_622519.wav"
languageCode = "korean"

max_retries = 10  # 최대 10번 재시도

for file_name in selected_files:
    file_path = os.path.join(audio_folder, file_name)
    json_path = os.path.join(json_folder, file_name.replace(".wav", ".txt"))

    print(f"Processing: {file_name}")

    file = open(file_path, "rb")
    audioContents = base64.b64encode(file.read()).decode("utf8")
    file.close()

    requestJson = {
        "argument": {
            "language_code": languageCode,
            "audio": audioContents
        }
    }

    http = urllib3.PoolManager()

    retries = 0
    while retries < max_retries:
        try:
            response = http.request(
                "POST",
                openApiURL,
                headers={"Content-Type": "application/json; charset=UTF-8", "Authorization": accessKey},
                body=json.dumps(requestJson),
                timeout=urllib3.Timeout(connect=5.0, read=30.0)  # 타임아웃 설정
            )
            res_json = json.loads(response.data)
            asr_text = res_json['return_object']['recognized']
            break  # 성공하면 반복 탈출
        except Exception as e:
            print(f"Request failed: {e}. Retrying ({retries+1}/{max_retries})...")
            retries += 1
            time.sleep(5)  # 2초 대기 후 재시도
    else:
        print("Failed after retries. Skipping this file.")
        continue

    if os.path.exists(json_path):
        with open(json_path, "r", encoding="utf-8") as f:
            data = f.read().strip()

            cer_result = metrics.get_cer(data, asr_text)
            cer = cer_result['cer']
            cer_list.append(cer)
            print(f"CER: {cer:.4f}")
    else:
        print("No reference text found.")

    print(f"Transcription: {asr_text}")
    print(f"Reference: {data}")
    print("-" * 50)

if cer_list:
    print(f"\nAverage CER: {sum(cer_list)/len(cer_list):.4f}")
# Out:
# Processing: KsponSpeech_539357.wav
# CER: 0.0417
# Transcription: 나는 어제 니 표정 보고 알았어. 쟤는 진짜 자기 싫어하는구나.
# Reference: 나는 어제 니 표정 보고 알았어. 쟤는 진짜 타기 싫어하는구나.
# --------------------------------------------------
# Processing: KsponSpeech_608138.wav
# CER: 0.1111
# Transcription: 그 제목 뭐였지? 우리들에 월급은 정 정당 안 가?
# Reference: 그 제목 뭐였지? 우리들의 월급은 정 정당한가?
# --------------------------------------------------
# Processing: KsponSpeech_618809.wav
# CER: 0.0000
# Transcription: 그 내 친구에 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비 비싼 데가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑
# Reference: 그 내 친구에 친구 중에 퍼스널 컬러를 세 번 받아본 애가 있어. 근데 제일 비 비싼 데가 있고 그냥 무난한 데가 있단 말이야. 근데 그게 그 차이가 그냥 퍼스널 컬러랑
# --------------------------------------------------
# Processing: KsponSpeech_524718.wav
# CER: 0.2000
# Transcription: 응. 그 추천 많이 해서.
# Reference: 응. 그거는 추천 많이 해서
# --------------------------------------------------
# Processing: KsponSpeech_585605.wav
# CER: 0.0000
# Transcription: 찹쌀탕수육.
# Reference: 찹쌀탕수육.
# --------------------------------------------------
# Processing: KsponSpeech_589709.wav
# CER: 0.0000
# Transcription: 되게 연기 잘하잖아.
# Reference: 되게 연기 잘하잖아.
# --------------------------------------------------
# Processing: KsponSpeech_592791.wav
# CER: 0.2500
# Transcription: 수웅이 알아? 수웅이?
# Reference: 수응이 알아? 수응이
# --------------------------------------------------
# Processing: KsponSpeech_603838.wav
# CER: 0.0870
# Transcription: 이케 좀 행사도 많고 좀 성수기인가 봐. 나름 그래가지구
# Reference: 이렇게 좀 행사도 많고 좀 성수기인가 봐. 나름 그래가지구
# --------------------------------------------------
# Processing: KsponSpeech_526034.wav
# CER: 0.0833
# Transcription: 시험 보고 들어오라 그래. 시험 보고 들어오라 그래. 경도 시험 보고 들어와야 돼. 내가 볼 거야. 내가 볼 거야. 내가 심사할 거야. 면접도 봐야겠다. 면접도 봐야겠다. 기초 소양
# Reference: 시험 보고 들어오라 그래 시험 보고 들어오라 그래. 경도 시험 보고 들어와야 돼. 내가 볼 거야 내가 볼 거야 내가 심사할 거야 면접도 봐야겠다 면접도 봐야겠다 기초소양 평가해가지고
# --------------------------------------------------
# Processing: KsponSpeech_608909.wav
# CER: 0.0000
# Transcription: 어차피 매출이 얼마가 나오든 물론 나랑은 상관이 없지만 어차피 난 똑같이 돈 받으니까.
# Reference: 어차피 매출이 얼마가 나오든 물론 나랑은 상관이 없지만. 어차피 난 똑같이 돈 받으니까.
# --------------------------------------------------
# Processing: KsponSpeech_534277.wav
# CER: 0.0000
# Transcription: 아니야. 애증은 아니야.
# Reference: 아니야 애증은 아니야.
# --------------------------------------------------
# Processing: KsponSpeech_524663.wav
# CER: 0.0000
# Transcription: 맞아.
# Reference: 맞아.
# --------------------------------------------------
# Processing: KsponSpeech_506541.wav
# CER: 0.0000
# Transcription: 근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까
# Reference: 근데 그거 그거를 뭐 하려고 해도 맨날 과제가 나오니까
# --------------------------------------------------
# Processing: KsponSpeech_550994.wav
# CER: 0.0588
# Transcription: 음 잘했어. 그럼 이제 배워볼 생각은 없어?
# Reference: 으음 잘했어. 그럼 이제 배워 볼 생각은 없어?
# --------------------------------------------------
# Processing: KsponSpeech_610899.wav
# CER: 0.0000
# Transcription: 얼마나 신선했으면 애벌레가 나왔니.
# Reference: 얼마나 신선했으면 애벌레가 나왔니
# --------------------------------------------------
# Processing: KsponSpeech_544963.wav
# CER: 0.0000
# Transcription: 아까 무슨 얘기 하고 있었지?
# Reference: 아까 무슨 얘기하고 있었지.
# --------------------------------------------------
# Processing: KsponSpeech_566814.wav
# CER: 0.0000
# Transcription: 네. 말씀하세요.
# Reference: 네. 말씀하세요.
# --------------------------------------------------
# Processing: KsponSpeech_617728.wav
# CER: 0.1667
# Transcription: 쫌 들어가야 돼.
# Reference: 좀 들어가야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_619452.wav
# CER: 0.0000
# Transcription: 나는 근데 생각보다 늦게 좋아해가지구 수능 끝나고 피 땀 눈물 나와서 그때부터 좋아했어.
# Reference: 나는 근데 생각보다 늦게 좋아해가지구 수능 끝나고 피 땀 눈물 나와서 그때부터 좋아했어.
# --------------------------------------------------
# Processing: KsponSpeech_609816.wav
# CER: 0.2174
# Transcription: 근데 난 이번에 쫌 열심히 해보께 그러면 끊으면 만약에.
# Reference: 근데 나는 이번에 좀 열심히 해 볼게 그러면. 끊으면 만약에
# --------------------------------------------------
# Processing: KsponSpeech_594199.wav
# CER: 0.0000
# Transcription: 나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까 그냥 거기는 쫌 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# Reference: 나는 근무를 하고 싶고 애초에 뭔가 뭐 거기 가서 살 생각까지 있으니까. 그냥 거기는 쫌 더 어떻게 우리나라랑 다른지 알고 싶더라고.
# --------------------------------------------------
# Processing: KsponSpeech_592002.wav
# CER: 0.0000
# Transcription: 발 뺀 거지?
# Reference: 발 뺀 거지?
# --------------------------------------------------
# Processing: KsponSpeech_555828.wav
# CER: 0.1250
# Transcription: 나는? 나는 내 6시 반에 알바 가야 되잖아. 오늘 처음 가잖아.
# Reference: 나는? 나는 나 여섯 시 반에 알바 가야 되잖아. 오늘 처음 가잖아.
# --------------------------------------------------
# Processing: KsponSpeech_544438.wav
# CER: 1.0000
# Transcription: 응.
# Reference: 음.
# --------------------------------------------------
# Processing: KsponSpeech_619033.wav
# CER: 0.5000
# Transcription: 오녀. 전복 맛. 전복 맛. 전복
# Reference: 아니야. 전복만. 전복만. 전복쓰
# --------------------------------------------------
# Processing: KsponSpeech_549073.wav
# CER: 0.0000
# Transcription: 역배를 하면은 커지지.
# Reference: 역배를 하면은 커지지.
# --------------------------------------------------
# Processing: KsponSpeech_595616.wav
# CER: 0.1500
# Transcription: 근데 아 아이를 안 좋아하면 사실 힘들지. 애들 다르 애들 TMI 얘기하는 거 보면 아 그게 너무 싫구나. 나는 좀 귀엽다고 얘기할래 그랬는데 싫구나.
# Reference: 근데 아 아일 안 좋아하면 사실 힘들지. 애들 다루 근데 애들 tmi 얘기하는 거 보면 아 그게 너무 싫구나? 나는 좀 귀엽다고 얘기할려 그랬는데. 싫구나.
# --------------------------------------------------
# Processing: KsponSpeech_529406.wav
# CER: 0.1667
# Transcription: 음 난리나. 본인이 말하고 싶어 못 참아해.
# Reference: 금 난리 나. 본인이 말하고 싶어 갖고 못 참아 해.
# --------------------------------------------------
# Processing: KsponSpeech_536673.wav
# CER: 0.0789
# Transcription: 막 어 진짜 막 잔인하게 잘 묘사해가지구 까 막 잔인한 장면은 안 나오는데 어 깜놀도 쫌 있구
# Reference: 막 어 진짜 막 잔인하게 잘 묘사해가지고 그니까 막 잔인한 장면은 안 나오는데 어 깜놀도 쫌 있구.
# --------------------------------------------------
# Processing: KsponSpeech_531484.wav
# CER: 0.1010
# Transcription: 응. 아침에? 아침에 이제 보통 다르지. 내가 학원을 갈 때가 있고 안 갈 때 했으니까 월, 수, 금 같은 경우는 학원을 내가 다니니까 좀 평소보다 일찍 일어나고 이제 그렇지 않을 때는 화, 목 같은 경우는 그냥 내가 일어나고 싶은 날 이런 일어나는.
# Reference: 응. 아침에? 아침에 이제 보통 다르지. 내가 학원을 갈 때가 있고 안 갈 때 있으니까. 월 수 금 같은 경우는 학원을 내가 다니니까 좀 평소보다 일찍 일어나고 이제 그렇지 않을 때는 화 목 같은 경우는 그냥 내가 일어나고 싶은 날 일어 일어나는 그런 식이지. 너는?
# --------------------------------------------------
# Processing: KsponSpeech_550925.wav
# CER: 0.0000
# Transcription: 나는 나는 나는 두 번인가 세 번 봤는데? 나는 언제 그렇게 봤지?
# Reference: 나는 나는 나는 두 번인가 세 번 봤는데? 나는 언제 그렇게 봤지?
# --------------------------------------------------
# Processing: KsponSpeech_568561.wav
# CER: 0.0000
# Transcription: 그거 오래됐어. 나는 보통 그거 한 한 달 쓰거든. 그 헤어팩
# Reference: 그거 오래됐어. 나는 보통 그거 한 한 달 쓰거든 그 헤어 팩
# --------------------------------------------------
# Processing: KsponSpeech_594468.wav
# CER: 0.0000
# Transcription: 웃기네.
# Reference: 웃기네.
# --------------------------------------------------
# Processing: KsponSpeech_564413.wav
# CER: 0.0370
# Transcription: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실 남넨데
# Reference: 그런 그런 훈훈한 그런 모습은 찾을 수가 없고 진짜 완전 현실 남맨데
# --------------------------------------------------
# Processing: KsponSpeech_544813.wav
# CER: 0.1875
# Transcription: 마우스 샀잖아. 아 마우스는 원래 이권 다.
# Reference: 마우스 샀잖아 아 마우스는 원래 있구.
# --------------------------------------------------
# Processing: KsponSpeech_586007.wav
# CER: 0.1429
# Transcription: 물 아 그래? 못 할걸?
# Reference: 물 아 구래? 못할걸?
# --------------------------------------------------
# Processing: KsponSpeech_515652.wav
# CER: 0.0000
# Transcription: 아 진짜로?
# Reference: 아 진짜로?
# --------------------------------------------------
# Processing: KsponSpeech_509494.wav
# CER: 0.0000
# Transcription: 그치. 정말
# Reference: 그치 정말.
# --------------------------------------------------
# Processing: KsponSpeech_622439.wav
# CER: 0.0000
# Transcription: 어 있어 그런 거.
# Reference: 어. 있어 그런 거.
# --------------------------------------------------
# Processing: KsponSpeech_523022.wav
# CER: 0.0000
# Transcription: 저기 혜화역.
# Reference: 저기 혜화역
# --------------------------------------------------
# Processing: KsponSpeech_517134.wav
# CER: 0.1667
# Transcription: 그니까. 그냥 모든 게 다 그런 거야. 지금 현 상황이 저러니까 모든 게 뭐 또 자식도 뭐 잘못한 것도 있지만 뭐 내조를 잘 못 하고 있나 그런 생각도 있고.
# Reference: 그니까 그냥 모든 게 다 그런 거야 지금 상황 형 상황이 요러니까. 어뜨케 보면 또 자식도 뭐 잘못한 것도 있지만. 뭐 내조를 잘못하고 있나? 그런 생각도 있.
# --------------------------------------------------
# Processing: KsponSpeech_602446.wav
# CER: 0.0417
# Transcription: 그니까 최근 말고 쫌 덜 최근? 그니까 내신 시험 할 때쯤에 최근?
# Reference: 그니까 최근 말고 좀 덜 최근 그니까 내신 시험할 때쯤에 최근
# --------------------------------------------------
# Processing: KsponSpeech_531126.wav
# CER: 0.4828
# Transcription: 5시나 여 6시까지겠지. 원래 나인 투 파이브잖아. 그래서
# Reference: 다섯 시나 여 여섯 시까지겠지? 원래 nine to five잖아 그래서.
# --------------------------------------------------
# Processing: KsponSpeech_566911.wav
# CER: 0.0000
# Transcription: 근데 중국에서 우연히 중국 사람들이 그 돌로 뭐
# Reference: 근데 중국에서 우연히 중국 사람들이 그 돌로 뭐.
# --------------------------------------------------
# Processing: KsponSpeech_578097.wav
# Request failed: HTTPConnectionPool(host='aiopen.etri.re.kr', port=8000): Read timed out. (read timeout=30.0). Retrying (1/10)...
# Request failed: HTTPConnectionPool(host='aiopen.etri.re.kr', port=8000): Read timed out. (read timeout=30.0). Retrying (2/10)...
# Request failed: HTTPConnectionPool(host='aiopen.etri.re.kr', port=8000): Read timed out. (read timeout=30.0). Retrying (3/10)...
# CER: 0.0000
# Transcription: 여성 징병이라 글쎄 근데 그런 것들이 진행이 될려면은
# Reference: 여성 징병이라 글쎄 근데 그런 것들이 진행이 될려면은
# --------------------------------------------------
# Processing: KsponSpeech_585961.wav
# CER: 0.0000
# Transcription: 심리가 비슷하다는 거지?
# Reference: 심리가 비슷하다는 거지?
# --------------------------------------------------
# Processing: KsponSpeech_601933.wav
# CER: 0.0000
# Transcription: 어쨌든 적당히 먹어야지.
# Reference: 어쨌든 적당히 먹어야지.
# --------------------------------------------------
# Processing: KsponSpeech_593839.wav
# CER: 0.3333
# Transcription: 나랑 잘 많더라고. 다이프 받고.
# Reference: 나랑 잘 맞더라고. 다 A 맞고.
# --------------------------------------------------
# Processing: KsponSpeech_496960.wav
# CER: 0.1765
# Transcription: 온통 쏠릴 거 같아서 3D를 선뜻 못 하겠어서 포장도 그렇게 많은 그건 아닌데
# Reference: 온통 쏠릴 거 같아서 쓰리디를 선뜻 못하겠 겠어서 포장도 그렇게 많은 그거는 아닌데.
# --------------------------------------------------
# Processing: KsponSpeech_521636.wav
# CER: 0.1148
# Transcription: 왜냐면 빨리 따 빨리 해 시작을 해야지 그게 빨리 쌓여 쌓여가지고 경력이 쌓이니까. 여기 쪼금 있다 가면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# Reference: 왜냐면 빨리 따야 빨리해 시작을 해야지 그게 빨리 쌓여 쌓여가지고 경력이 쌓이니까. 이게 조금 이따가 하면 또 나중에 다 까먹고 이러면 또 그게 안 되니까.
# --------------------------------------------------
# Processing: KsponSpeech_577689.wav
# CER: 0.0857
# Transcription: 어 거 어 누나는 이제 집에 없지. 결혼했지. 집에 없 근데 가끔 누나 가서 도와줄 수도 있는데
# Reference: 어. 커 아 누나는 이제 집에 없지. 결혼 했지. 집에 없 근데 가끔 누나 가서 도와줄 수 있는데
# --------------------------------------------------
# Processing: KsponSpeech_608974.wav
# CER: 0.0000
# Transcription: 남자 친구가 없어 하면은 굉장히 그 어머니가 불안해하더라고. 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데
# Reference: 남자 친구가 없어 하면은 굉장히 그 어머니가 불안해하더라고. 그래서 예전부터 뭐 이사 문제도 그렇고 굉장히 많이 불안해하시고 했는데
# --------------------------------------------------
# Processing: KsponSpeech_609729.wav
# CER: 0.0385
# Transcription: 근데 난 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 거 같애.
# Reference: 데 난 여기서 더 이상 빼면은 더 이상 나는 작은 마음이 될 거 같애
# --------------------------------------------------
# Processing: KsponSpeech_573323.wav
# CER: 0.0000
# Transcription: 그래서 내가 그 신경 치료까지 했단 말이야. 신경이 죽어가지고
# Reference: 그래서 내가 그 신경 치료까지 했단 말이야. 신경이 죽어가지고.
# --------------------------------------------------
# Processing: KsponSpeech_610233.wav
# CER: 0.0000
# Transcription: 그니까 그 생각하니까
# Reference: 그니까 그 생각하니까.
# --------------------------------------------------
# Processing: KsponSpeech_574615.wav
# CER: 0.4516
# Transcription: 입각권을 이제 10% 가산점을 주니까 어 90프로 100분이 맞는 얘들도
# Reference: 이과 꺼는 이제 십 프로 가산점을 주니까 어 구십 프로 백분위 맡는 얘들도
# --------------------------------------------------
# Processing: KsponSpeech_510618.wav
# CER: 0.1429
# Transcription: 완전 아니 132명 뽑는데 컷 점수가 백 백 내 점수야. 컷 점수가 그러니까 나랑 동점자가 이제 꼴진 거야.
# Reference: 완전 아니 백 삼십 이 명 뽑는데 컷 점수가 백 배 내 점수야 컷 점수가 그니까 나랑 동점자가 이제 꼴진 거야
# --------------------------------------------------
# Processing: KsponSpeech_576594.wav
# CER: 0.0000
# Transcription: 그런 데가 있구나. 니가 가자고 한 데가 거기야?
# Reference: 그런 데가 있구나 니가 가자고 한데가 거기야?
# --------------------------------------------------
# Processing: KsponSpeech_542633.wav
# CER: 0.1111
# Transcription: 아빠 50살 된다 했던 게 엊그제 같은데 진짜.
# Reference: 아빠 오십 살 된다 했던 게 엊그제 같은데 진짜.
# --------------------------------------------------
# Processing: KsponSpeech_588225.wav
# CER: 0.0777
# Transcription: 고런 거? 그때마다 걔가 이케 뭘 넣어주긴 안 넣어준 건 아니거든 넣어주긴 넣어줬는데 쫌 쫌 내가 느끼기에는 얘가 나를 생각해서 사오 거라기보다는 집에 남는 거 있잖아. 뭔가 엄마가 사오셨는데 집에 쟁여두고 있다가 하나씩 갔다가 나를 주는 거 같은.
# Reference: 고런 거? 그때마다 걔가 이렇게 뭘 넣어주는 안 넣어준 건 아니거든? 넣어주긴 넣어줬는데 쫌 쫌 내가 느끼기에는 얘가 나를 생각해서 사 온 거라기보다는 집에 남는 거 있잖아? 뭔가 엄마가 사 오셨는데 집에 이렇게 쟁여두고 있다가 하나씩 갖다가 나를 주는 거 같은.
# --------------------------------------------------
# Processing: KsponSpeech_517345.wav
# CER: 0.0606
# Transcription: 아 내 생각엔 안경 땜에 좀 걸쳐지는 게 불편했나? 근데 너 안경 못 쓰니까 딴 사람 같아.
# Reference: 아 내 생각엔 안경 땜에 좀 걸쳐지는 게 불편했나? 근데 너 안경 벗으니까 딴 사람 같아.
# --------------------------------------------------
# Processing: KsponSpeech_617232.wav
# CER: 0.0000
# Transcription: 자기가 너무 크니까.
# Reference: 자기가 너무 크니까.
# --------------------------------------------------
# Processing: KsponSpeech_527157.wav
# CER: 0.0000
# Transcription: 그럴 거 같지? 우리 다음 주부터 둘 다 출근할 거 같으니까 주말 주말은 너무하니까 금요일?
# Reference: 그럴 거 같지? 우리 다음 주부터 둘 다 출근할 거 같으니까. 주말 주말은 너무하니까 금요일?
# --------------------------------------------------
# Processing: KsponSpeech_561775.wav
# CER: 0.1333
# Transcription: 그니까 탄산음료 먹고 싶을 때 있잖아.
# Reference: 이까 탄산음료 먹고 싶을 때 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_551757.wav
# CER: 0.0000
# Transcription: 군 그냥 나 혼자 그렇게 생각하는 건데.
# Reference: 군 그냥 나 혼자 그렇게 생각하는 건데?
# --------------------------------------------------
# Processing: KsponSpeech_605994.wav
# CER: 0.0000
# Transcription: 나 공부해야 돼.
# Reference: 나 공부해야 돼.
# --------------------------------------------------
# Processing: KsponSpeech_502392.wav
# CER: 0.0385
# Transcription: 근데 약간 우리 오빠는 그거 잘해. 자기 혼자 영어 홍보 마케팅 다 해.
# Reference: 근데 약간 우리 오빠는 그거 잘해. 자기 혼자 영업 홍보 마케팅 다 해.
# --------------------------------------------------
# Processing: KsponSpeech_573125.wav
# Request failed: HTTPConnectionPool(host='aiopen.etri.re.kr', port=8000): Read timed out. (read timeout=30.0). Retrying (1/10)...
# Request failed: HTTPConnectionPool(host='aiopen.etri.re.kr', port=8000): Read timed out. (read timeout=30.0). Retrying (2/10)...
# Request failed: HTTPConnectionPool(host='aiopen.etri.re.kr', port=8000): Read timed out. (read timeout=30.0). Retrying (3/10)...
# CER: 0.2000
# Transcription: 아 받은 거야 엄마한테?
# Reference: o. 아 받은 거여. 엄마한테?
# --------------------------------------------------
# Processing: KsponSpeech_611873.wav
# CER: 0.0625
# Transcription: 그 해리포터 영화 자체가 전체 다 영국인이고 거기서 나오는 동양인이라도 영국에 사는 사람이고 그래서 되게 사람들이
# Reference: 그 해리포터 영화 자체가 전체 다 영국인이고 거기서 나오는 동양인이라도 영국에 사는 사람이고 계속되게 사람들이
# --------------------------------------------------
# Processing: KsponSpeech_549930.wav
# CER: 0.0714
# Transcription: 살 건 아니고 그냥 혼자서 아이쇼핑을 하면서 혹이나 눈에 띄는 게 있다면 득테마로 가는 거지. 굳이 내가 뭘 살려고 가는 것은 아니다. 그런 거지.
# Reference: 살 건 아니고 그냥 혼자서 아이 쇼핑을 하면서 혹이나 눈에 띄는 게 있다면 득템하러 가는 거지. 꾿이 내가 뭘 살려고 가는 것은 아니다 그런 거지.
# --------------------------------------------------
# Processing: KsponSpeech_584024.wav
# CER: 0.6250
# Transcription: 뭐가 수위거나 하자.
# Reference: 모가 수위가 낮아.
# --------------------------------------------------
# Processing: KsponSpeech_514225.wav
# CER: 0.0556
# Transcription: 그 첫 번째 년도에 못 가고 그다음 연도에 왔어.
# Reference: 그 첫 번째 년도에 못 가고 그 다음 연도에 갔어.
# --------------------------------------------------
# Processing: KsponSpeech_539926.wav
# CER: 0.0000
# Transcription: 그래. 빨리 보내줘.
# Reference: 그래 빨리 보내줘
# --------------------------------------------------
# Processing: KsponSpeech_540647.wav
# CER: 0.0000
# Transcription: 너는 여행 안 가?
# Reference: 너는 여행 안 가?
# --------------------------------------------------
# Processing: KsponSpeech_505546.wav
# CER: 0.0333
# Transcription: 그 병인이라는 사람이 2학기 때 했잖아. 너무 놀고 돈만 먹고 놀고 있는 거야.
# Reference: 그 병인이라는 사람이 이 학기 때 했잖아. 너무 놀고 돈만 먹고 놀고 있는 거야.
# --------------------------------------------------
# Processing: KsponSpeech_510540.wav
# CER: 0.0000
# Transcription: 그치.
# Reference: 그치.
# --------------------------------------------------
# Processing: KsponSpeech_574951.wav
# CER: 0.2759
# Transcription: 몇 명 정도 있어. 어이있는 나가라 했다고. 그대는 약간 배척당하지 않을까?
# Reference: 몇 명 정도 있어? 어인의 나라가 있다고? 걔네는 약간 배척당하지 않을까?
# --------------------------------------------------
# Processing: KsponSpeech_547184.wav
# CER: 0.0714
# Transcription: 아 근데 모르겠어. 걔가 하는 말이 가끔씩 쫌 약간 거부감이 될 때가 있긴 있었어. 동아리를 같이 했었으니까.
# Reference: 아 근데 모르겠어. 걔가 하는 말이 가끔씩 쫌 약간 거부감이 들 때가 있긴 있었어. 동아릴 같이했었으니까.
# --------------------------------------------------
# Processing: KsponSpeech_596750.wav
# CER: 0.0588
# Transcription: 그래서 그냥 쫌 약간 입고 가기 부담스러워.
# Reference: 그래서 그냥 좀 약간 입고 가기 부담스러워.
# --------------------------------------------------
# Processing: KsponSpeech_529908.wav
# CER: 0.2000
# Transcription: 에 나 싱크홀.
# Reference: 에 다 싱크홀.
# --------------------------------------------------
# Processing: KsponSpeech_612661.wav
# CER: 0.0000
# Transcription: 너무 아깝더라. 누나랑 같이 보는데 재미도 없고.
# Reference: 너무 아깝더라. 누나랑 같이 보는데 재미도 없고
# --------------------------------------------------
# Processing: KsponSpeech_615557.wav
# CER: 0.1176
# Transcription: 그 홍보대사 같은 거 아니면 내가 알기론
# Reference: 그 홍보대사 같은 거 아니면 내가 알기로는.
# --------------------------------------------------
# Processing: KsponSpeech_536215.wav
# CER: 0.1667
# Transcription: 한 1시 반까지만 마시면 되지. 그때가 인제 지하철이 있잖아.
# Reference: 한 한 시 반까지만 마시면 되지. 그때까진 지하철이 있잖아.
# --------------------------------------------------
# Processing: KsponSpeech_593491.wav
# CER: 0.0000
# Transcription: 올 땐 데리러 올 거야. 아니면 인천공항에서 만나던가.
# Reference: 올 땐 데리러 올 거야 아니면 인천공항에서 만나던가.
# --------------------------------------------------
# Processing: KsponSpeech_520848.wav
# CER: 0.0000
# Transcription: 치즈 함박 스테이크?
# Reference: 치즈 함박 스테이크?
# --------------------------------------------------
# Processing: KsponSpeech_585460.wav
# CER: 0.1667
# Transcription: 갔다. 어 면제 갔다 왔어. 옛날에 갔다 왔구나.
# Reference: 갔다 온. 너 언제 갔다 왔어. 옛날에 갔다 왔구나.
# --------------------------------------------------
# Processing: KsponSpeech_611985.wav
# CER: 0.0000
# Transcription: 어 그치.
# Reference: 어 그치.
# --------------------------------------------------
# Processing: KsponSpeech_509670.wav
# CER: 0.2222
# Transcription: 청소년으로 보면 좀 싸.
# Reference: 청소년으로 보내 줌 싸.
# --------------------------------------------------
# Processing: KsponSpeech_592064.wav
# CER: 0.1333
# Transcription: 눈이 상태니까 어떤지 계속 봐야 된대.
# Reference: 눈이 상태가 어떤지 계속 봐야 된대.
# --------------------------------------------------
# Processing: KsponSpeech_509147.wav
# CER: 0.0645
# Transcription: 수능 봤는데 재수했거든? 재수했는데 그 덕성여댄가? 거기 논술로 잡혔대. 어.
# Reference: 수능 봤는데 재수했거든? 재수했는데 그 덕성여대인가? 거기 논술로 잡혔대 어
# --------------------------------------------------
# Processing: KsponSpeech_608811.wav
# CER: 0.0256
# Transcription: 그리고 우리 저번 이번에도 저번 달인가? 몇 주 전에 고척 스카이돔에서 하는 축 그 숙제 가지 않았어?
# Reference: 그리고 우리 저번 이번에도 저번 달인가 몇 주 전에 고척스카이돔에서 하는 축 그 축제 가지 않았어?
# --------------------------------------------------
# Processing: KsponSpeech_573353.wav
# CER: 0.0000
# Transcription: 그 시간 동안 내가 하고 싶은 걸 좀 하다가 이제
# Reference: 그 시간 동안 내가 하고 싶은 걸 좀 하다가 이제.
# --------------------------------------------------
# Processing: KsponSpeech_586029.wav
# CER: 0.0000
# Transcription: 우리 지금 하루 텀 있고 만났어.
# Reference: 우리 지금 하루 텀 있고 만났어.
# --------------------------------------------------
# Processing: KsponSpeech_563030.wav
# CER: 0.1333
# Transcription: 보니까? 연예인 발견은? 돈 내는 거였어?
# Reference: 보니까? 연애에 발견은? 돈 내는 거였어?
# --------------------------------------------------
# Processing: KsponSpeech_538803.wav
# CER: 0.0000
# Transcription: 빼박이지 이러면.
# Reference: 빼박이지 이러면.
# --------------------------------------------------
# Processing: KsponSpeech_512824.wav
# CER: 0.0000
# Transcription: 가영이랑 승원이랑
# Reference: 가영이랑 승원이랑
# --------------------------------------------------
# Processing: KsponSpeech_575385.wav
# CER: 0.0244
# Transcription: 강식당 하면 이번에는 더 재밌을 거 같다. 피오 있어서 피오가 강식당 이번에 쫌 톡톡히 할 거 같은데 그치?
# Reference: 강 식당 하면 이번에는 더 재밌을 거 같다. 피오 있어서 피오가 강 식당 이번에 쫌 톡톡히 할 거 같은데. 그체.
# --------------------------------------------------
# Processing: KsponSpeech_600850.wav
# CER: 0.2222
# Transcription: 주말 수당은 줘도 야근 수당은 안 주는 덴 많지.
# Reference: 주말 수당은 줘도 야근 수당 안 준 데는 많지.
# --------------------------------------------------
# Processing: KsponSpeech_574095.wav
# CER: 0.0000
# Transcription: 아 이번에 내 친구 경찰 공무원 준비하는데 붙었다?
# Reference: 아 이번에 내 친구 경찰공무원 준비하는데 붙었다.
# --------------------------------------------------
# Processing: KsponSpeech_576092.wav
# CER: 0.0000
# Transcription: 근 날만이구나.
# Reference: 근 날만이구나.
# --------------------------------------------------
#
# Average CER: 0.0909
